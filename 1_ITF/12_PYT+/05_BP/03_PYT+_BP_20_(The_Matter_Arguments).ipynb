# %%
# 3_Python+_Ders_3_The_Matter_Arguments_06_06_2021

# %%
# The Matter of Arguments

# %%
# Arguments vs Parameters

# %%
def who(first, last) :  # 'first' and 'last' are the parameters(or variables)
    print('Your first name is :', first)
    print('Your last name is :', last)

who('Guido', 'van Rossum')  # 'Guido' and 'van Rossum' are the arguments
print()
who('Marry', 'Bold')  # 'Marry' and 'Bold' are also the arguments
# Out:
# Your first name is : Guido
# Your last name is : van Rossum
#
# Your first name is : Marry
# Your last name is : Bold

# %%
def who(first, last) :
    print('Your first name is :', first)
    print('Your last name is :', last)

who('Guido') # we passed only one argument into the function, it gives error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-99fde431ce54> in <module>
#       3     print('Your last name is :', last)
#       4
# ----> 5 who('Guido') # we passed only one argument into the function, it gives error
#
# TypeError: who() missing 1 required positional argument: 'last'

# %%
# Be careful. The order of parameters in the function must match the order of arguments you passed into.

# %%
# Correct Use of Arguments

# %%
# Positional Arguments

# %%
# When calling a function with positional arguments, they must be passed in order from left to right.

# %%
def pos_args(a, b):
    print(a, 'is the first argument')
    print(b, 'is the second argument')

pos_args(3,4)
print()
pos_args(4,3)
# Out:
# 3 is the first argument
# 4 is the second argument
#
# 4 is the first argument
# 3 is the second argument

# %%
pos_args('first','second')
print()
pos_args('second', 'first')
# Out:
# first is the first argument
# second is the second argument
#
# second is the first argument
# first is the second argument

# %%
# Keyword Arguments

# %%
# Commonly and traditionally, kwargs is used as an abbreviation of keyword arguments.
# The formula syntax is : kwargs=values.

# %%
def who(first, last) :  # same structure as the previous one
    print('Your first name is :', first)
    print('Your last name is :', last)

who(first='Guido', last='van Rossum')
# calling the function is different
# we used kwargs to pass the values into the function
# Out:
# Your first name is : Guido
# Your last name is : van Rossum

# %%
def who(first, last) :
    print('Your first name is :', first)
    print('Your last name is :', last)

who('Guido', 'van Rossum')
# Out:
# Your first name is : Guido
# Your last name is : van Rossum

# %%
def parrot(voltage, state='a stiff', action='voom', type='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", type)
    print("-- It's", state, "!")
# accepts one required argument (voltage) and three optional arguments (state, action, and type).
# This function can be called in any of the following ways:

# %%
parrot(1000)                                          # 1 positional argument
parrot(voltage=1000)                                  # 1 keyword argument
parrot(voltage=1000000, action='VOOOOOM')             # 2 keyword arguments
parrot(action='VOOOOOM', voltage=1000000)             # 2 keyword arguments 
parrot('a million', 'bereft of life', 'jump')         # 3 positional arguments
parrot('a thousand', state='pushing up the daisies')  # 1 positional, 1 keyword
# Out:
# -- This parrot wouldn't voom if you put 1000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't voom if you put 1000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't VOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't VOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't jump if you put a million volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's bereft of life !
# -- This parrot wouldn't voom if you put a thousand volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's pushing up the daisies !

# %%
# If you have noticed the positions of the parameters voltage and action,
# sequences or positions don't matter when using keyword arguments.

# %%
parrot()                     # required argument missing
parrot(voltage=5.0, 'dead')  # non-keyword argument after a keyword argument
parrot(110, voltage=220)     # duplicate value for the same argument
parrot(actor='John Cleese')  # unknown keyword argument
# Out:
#   File "<ipython-input-24-2ac707ad11c1>", line 2
#     parrot(voltage=5.0, 'dead')  # non-keyword argument after a keyword argument
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
# In a function call: 
# keyword arguments must follow positional arguments.
# All the keyword arguments passed must match one of the arguments accepted by the function (e.g. actor is not a valid argument for the parrot function), and their order is not important.
# This also includes non-optional arguments (e.g. parrot(voltage=1000) is valid too).
# No argument may receive a value more than once.

# %%
def function(a):
    pass  # actually, 'pass' does nothing. it just moves to the next line of code

function(0, a=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-25a27cb536b4> in <module>
#       2     pass  # actually, 'pass' does nothing. it just moves to the next line of code
#       3
# ----> 4 function(0, a=0)
#
# TypeError: function() got multiple values for argument 'a'

# %%
# In a function call, keyword arguments must follow positional arguments.

# %%
def function():
    pass  

function()

# %%
def city(capital, continent='Europe'):
    print(capital, 'in', continent)

city('Athens')  # we don't have to pass any arguments into 'continent'
city('Ulaanbaatar', continent='Asia')  # we can change the default value by kwargs
city('Cape Town', 'Africa')  # we can change the default value by positional args.
# Out:
# Athens in Europe
# Ulaanbaatar in Asia
# Cape Town in Africa

# %%
def fruiterer(fruit1, fruit2) :
    print('I want to get', fruit1, 'and', fruit2)
        
fruiterer('orange', 'banana')
# Out:
# I want to get orange and banana

# %%
def fruiterer(*fruit) :             # With List or Tuple
    print('I want to get :')
    for i in fruit :
        print('-', i)
        
fruiterer('orange', 'banana', 'melon', 'ananas')
# Out:
# I want to get :
# - orange
# - banana
# - melon
# - ananas

# %%
def animals(**kwargs):              # With dictionary
    for key, value in kwargs.items():
        print(value, "are", key)

# animals = {"Carnivores" : "Lions", "Omnivores" : "Bears", "Herbivores" : "Deers", "Nomnivores" : "Human"}  # burada da bu formatta olmuyor 
animals(Carnivores="Lions", Omnivores="Bears", Herbivores="Deers", Nomnivores="Human")

# %%
def brothers(bro1, bro2, bro3) :
    print("Here are the names of brothers :")
    print(bro1, bro2, bro3, sep="\n")
family = ["tom", "sue", "tim"]
brothers(*family)
# Out:
# Here are the names of brothers :
# tom
# sue
# tim

# %%
def gene(x, y):  # defined by positional args
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")
 
dict_gene = {'y' : "Marry", 'x' : "Fred"}
# dict_gene(y="Marry", x="Fred")  # TypeError: 'dict' object is not callable
gene(**dict_gene)  # we call the function by a single argument(variable)
# Out:
# Fred belongs to Generation X
# Marry belongs to Generation Y

# %%
def gene(x='Solomon', y='David'):  # defined by kwargs (default values assigned to x and y)
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")
 
dict_gene = {'y' : "Marry", 'x' : "Fred"}
gene(**dict_gene)
# Out:
# Fred belongs to Generation X
# Marry belongs to Generation Y

# %%
# Youtube Channel Video-1

# %%
def get_initial(name) :
    initial = name[0:1].upper()
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name)

print("Your initial is : " + first_name_initial)
# Out:
# Your initial is : E

# %%
def get_initial(name, force_uppercase) :  # default olarak birşey vermedik force_uppercase
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name, False)

print("Your initial is : " + first_name_initial)
# Out:
# Your initial is : e

# %%
def get_initial(name, force_uppercase = True) :  # defoult olarak True
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name)

print("Your initial is : " + first_name_initial)
# Out:
# Your initial is : E

# %%
def get_initial(name, force_uppercase) :
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(force_uppercase=True, name = first_name)

print("Your initial is : " + first_name_initial)
# Out:
# Your initial is : E

# %%
def error_logger(error_code, error_severity, log_to_db, error_message, source_module) :
    print("oh no error :" + error_message)
    # Imagine code here that logs our error to a database or file

first_number = 10
second_number = 5
if first_number > second_number :
    error_logger(45, 1, True, "Second number greater than first", "my_math_method")
# Out:
# oh no error :Second number greater than first

# %%
def error_logger(error_code, error_severity, log_to_db, error_message, source_module) :
    print("oh no error :" + error_message)
    # Imagine code here that logs our error to a database or file

first_number = 10
second_number = 5
if first_number > second_number :
    error_logger(error_code = 45, error_severity = 1, log_to_db = True, error_message = "Second number greater than first", source_module = "my_math_method")
# Out:
# oh no error :Second number greater than first

# %%
# Youtube Channel Video-2

# %%
def get_initial(name) :
    initial = name[0:1].upper()
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name)

print("Your initial is :", first_name_initial)
# Out:
# Your initial is : E

# %%
def get_initial(name, force_uppercase) :  # default True döner
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name, False)  # do not force to uppercase

print("Your initial is :", first_name_initial)
# Out:
# Your initial is : e

# %%
def get_initial(name, force_uppercase = True) :  # True döner ancak aşağıda False var
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name, False)  # do not force to uppercase

print("Your initial is :", first_name_initial)
# Out:
# Your initial is : e

# %%
def get_initial(name, force_uppercase = True) :  # True döner ve zorlar uppercase
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(first_name)

print("Your initial is :", first_name_initial)
# Out:
# Your initial is : E

# %%
def get_initial(name, force_uppercase = True) :
    if force_uppercase :
        initial = name[0:1].upper()
    else :
        initial = name[0:1]
    return initial

first_name = input("Enter your first name :")
first_name_initial = get_initial(force_uppercase = False, name = first_name)  # upper zorlama

print("Your initial is :", first_name_initial)
# Out:
# Your initial is : e

# %%
def team_names(*teams) :
    print('The teams in Premier League are :')
    for i in teams :
        print('-', i)

team_names('Liverpool', 'M.United', 'M.City', 'Arsenal')
# Out:
# The teams in Premier League are :
# - Liverpool
# - M.United
# - M.City
# - Arsenal

# %%
def make_sentence(**kwargs):
    result = ""
    # Iterating over the Python kwargs dictionary
    for i in kwargs.values():
        result += i
    return result

print(make_sentence(a="I ", b="love ", c="Clarusway!"))
# Out:
# I love Clarusway!

# %%
def team_league(team, league='Premier League'):
    print(team, 'in', league)

team_league('Liverpool')
# Out:
# Liverpool in Premier League

# %%
def my_function(first, last) : 
    print('Your first name is :', first)
    print('Your last name is :', last)

my_function(first='Richard', last='Rice')
# Out:
# Your first name is : Richard
# Your last name is : Rice

# %%
def my_function(first, last) : 
    print('Your first name is :', first)
    print('Your last name is :', last)

my_function('Richard', 'Rice')
# Out:
# Your first name is : Richard
# Your last name is : Rice
