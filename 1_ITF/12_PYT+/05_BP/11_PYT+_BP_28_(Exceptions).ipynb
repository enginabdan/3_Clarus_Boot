# %%
# 11_Python+_Ders_11_Exceptions_10_06_2021

# %%
# Exceptions

# %%
# even if you have not made a syntax error, your program will be executed to a certain line and then give some warning messages.
# This means that your program is partially executed. Well, let's figure out what is going on.

# %%
# Syntax Error : These types of errors are detected during "compiling" the program into byte-code.
# Exception Error : These types of errors are detected during the program "execution" ("interpretation") process.
# Some of the examples of exceptions are - ZeroDivisionError, TypeError and NameError.

# %%
print('Here we go!')
print('I will be the second text')
a = '3'
b = 5
print('It is time for an error message :(')
print(a + b)  # it won't be printed
print("Sorry, but I won't be printed")  # it won't be printed
# Out:
# Here we go!
# I will be the second text
# It is time for an error message :(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a8bfc29e0ece> in <module>
#       4 b = 5
#       5 print('It is time for an error message :(')
# ----> 6 print(a + b)  # it won't be printed
#       7 print("Sorry, but I won't be printed")  # it won't be printed
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Common Exceptions
# 1. ValueError : problem with the content of the object you tried to assign the value to
# 2. NameError : variable you use in the code stream is not pre-defined or not properly defined
# 3. TypeError : operation or function is applied to an object of inappropriate type

# %%
# ValueError
print(int('ten'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0ceea5491468> in <module>
#       1 # ValueError
# ----> 2 print(int('ten'))
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
# NameError
print(variable)
variable = "Don't ever give up!"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cdac886a7f1f> in <module>
#       1 # NameError
# ----> 2 print(variable)
#       3 variable = "Don't ever give up!"
#
# NameError: name 'variable' is not defined

# %%
# TypeError
for i in range('x'):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d997526e502a> in <module>
#       1 # TypeError
# ----> 2 for i in range('x'):
#       3     print(i)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
# The most useful way you can do about all the errors you can't deal with yourself is to search for the error message on the internet search engine.
# You can make sure that the errors that you will encounter and their solutions have been experienced by someone previously.

# %%
# TypeError- It occurs when the expected type does not match with the given type of a variable.
# ValueError- It occurs when an expected value is not given, suppose you are expecting 6 elements in a list and you gave 2.
# NameError- It occurs when you are trying to access an undefined variable or a function.
# IOError- It occurs when you are trying to access a file that does not exist.
# IndexError- It occurs when you are trying to access an invalid index of a sequence.
# KeyError- It occurs when you use an invalid key to access a value in the dictionary.
