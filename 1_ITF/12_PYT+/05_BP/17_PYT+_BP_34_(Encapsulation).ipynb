# %%
# 17_Python+_Ders_17_Encapsulation_12_06_2021

# %%
# Here comes the question: can your code be more precise about what parts of it are for the public access and what are not?

# %%
# Most programming languages that implement the object-oriented paradigm can provide you with those tools.

# %%
# Encapsulation

# %%
# Encapsulation refers to bundling data with the methods operating with it while restricting direct access to some components.

# %%
# Getters and Setters

# %%
# You can create a class with some data that no one can change, while it is also possible to provide it with some safety mechanism prohibiting any modification.

# %%
# which is also a common practice in many object-oriented languages, is to create methods to get and set data.

# %%
# These methods are known as getters and setters.

# %%
# Using setters, we can declare that there should be an actor to change an object.
# Moreover, with the SET method, we can check if the new data are correct, and if it doesn't break the consistency of an object.
# In case it does, we can prevent the operation from causing that.

# %%
# Domain-Specific Methods

# %%
# Assume that you're working on the CLOCK class.
# What are the operations that you can provide a user with to change the time?
# It can be SET_TIME, but if the user wants to change the time more granularly, you can create such methods as ADD_HOUR, ADD_MINUTE, ADD_SECONDS.
# Now we can emulate the real action for our domain of knowledge.

# %%
# Protecting Data

# %%
# The problem of protecting the data doesn't have a universal solution for all the programming languages.
# Some of them give you keywords to restrict access to the attributes of a class.
# Others can have name conventions or even name mangling.

# %%
# Some languages are using keywords to set the visibility for the fields of a class.

# %%
# The other method is the name conventions. For example, you can set up a rule that all the attributes starting with a capital letter are public, but all the variables starting with a lowercase letter are accessible only in the inner scope.

# %%
# Name mangling is a principle of changing a field name for external access.

# %%
# 3 If you want to give read-only access to the field, you should use a getter.
