# %%
# 9_Python+_Ders_9_Program_Execution_10_06_2021

# %%
# Typed Script
# Interpretation
# Everything is done!

# %%
# heard terms such as interpreted or compiled languages.

# And most likely, you learned that Python was an interpreted type of programming language.

# %%
# Python's default interpreter is a software written in the C programming language known as CPython. 
# There are several other interpreters available such as :

# %%
# ---Jython--- :Java-based algorithm,
# Python codes into Java-compatible byte code,
# executed later by the Java Virtual Machine.

# %%
# ---PyPy--- is a replacement for CPython.
# built using the RPython language.
# The main reason to use it instead of CPython is speed.
# RPython (Restricted Python) provides some restrictions to the usual Python code.

# %%
# ---IronPython--- is an open-source,
# tightly integrated with the .NET Framework.

# %%
# Interpretation
# 1. Compilation
# 2. Byte Code
# 3. Virtual Machine

# %%
# ---Compilation---
# translates your Python statements (source code) into byte-code.
# the byte code is platform-independent, primitive level and specific version of the Python source code.
# That's why some Python programs are executed not as fast as in C-based conventional compiled languages.

# %%
# ---Python Virtual Machine---

# %%
# Lastly, we can say that the actual execution of the Python codes we typed is done by Python Virtual Machine as the last step.
# In fact, other previous steps are the process of converting Python statements into a format that Python Virtual Machine can understand and execute.
