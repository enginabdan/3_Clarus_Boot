# %%
# 15_Python+_Ders_15_Working_With_CSV_Files_12_06_2021

# %%
# Working with the CSV Files

# %%
# What is a CSV File?

# %%
# CSV stands for Comma Separated Values.

# %%
# Actually, it's a plain text like .txt files.
# Normally, CSV files use a comma to separate each specific data value.
# When you save the plain text file that you create by using a simple text editor (such as Notepad in Windows OS) as a .csv extension, then you create a CSV file.

# %%
# A CSV file is basically a table made up of rows and columns.
# The structure of a simple CSV file is as follows :

# %%
column 1,column 2,column 3
first row 1,first row 2,first row 3
second row 1,second row 2,second row 3
third row 1,third row 2,third row 3
.
.
.

# %%
# Now, let's create our first CSV file.
# save this file with a .csv extension into directory pwd.

# %%
# Reading Methods of the CSV Files
# 1. You can use the ordinary way of reading using open() function and .read() method just you learned in the previous lesson.
# 2. You can use csv Module.
# 3. You can use the Pandas library for which created data analysis purposes. It is highly recommended if you have a lot of data to analyze. We will not examine this scientific library in this topic. You can learn it if you attend the Data Science course.

# %%
# Ordinary Reading Method of CSV Files

with open("fruits.csv", 'r', encoding="utf-8") as file:
   print(file.read())
# Out:
# no,fruit,amount
# 1,Banana,4 lb
# 2,Orange,5 lb
# 3,Apple,2 lb
# 4,Strawberry,6 lb
# 5,Cherry,3 lb

# %%
# Reading the CSV Files with 'csv' Module

# %%
# First of all, of course, we should load csv module.
# Secondly, we will use csv.reader() function in a for loop to read the CSV file.

# %%
import csv  # loads csv module

with open("fruits.csv", 'r', newline = '', encoding = 'utf-8') as file:
    csv_rows = csv.reader(file)  # reader() function takes each
                                 # row (lines) into a list
    for row in csv_rows: 
        print(row)
# Out:
# ['no', 'fruit', 'amount']
# ['1', 'Banana', '4 lb']
# ['2', 'Orange', '5 lb']
# ['3', 'Apple', '2 lb']
# ['4', 'Strawberry', '6 lb']
# ['5', 'Cherry', '3 lb']

# %%
# As you can see, the rows are displayed in the list type.

# %%
# If newline='' is not specified, newlines embedded inside quoted fields will not be interpreted correctly, and on platforms that use \r\n linendings on write an extra \r will be added.
# It is best practice and always safe to specify newline='', since the csv module does its own newline handling.

# %%
# The default value of the delimiter parameter is ",".
# Thus, we can display each comma-separated element as separate strings.
# At this time let's use the delimiter="," parameter and see the same result as the previous one.

# %%
import csv

with open("fruits.csv", 'r', newline = '', encoding = 'utf-8') as file:
    csv_rows = csv.reader(file, delimiter= ",")  # gives the same output as the previous one
                                 
    for row in csv_rows: 
        print(row)
# Out:
# ['no', 'fruit', 'amount']
# ['1', 'Banana', '4 lb']
# ['2', 'Orange', '5 lb']
# ['3', 'Apple', '2 lb']
# ['4', 'Strawberry', '6 lb']
# ['5', 'Cherry', '3 lb']

# %%
# We can also display each row in the list as a single string.
# If we determine a character that is not included in the CSV file and allocate this character as the value of delimiter, we can print all lines of the CSV file as lists as a single string element.

# %%
import csv 

with open("fruits.csv", 'r', newline = '', encoding = 'utf-8') as file:
    csv_rows = csv.reader(file, delimiter = ':')  # we specified a char ":" that is not used
                                                  # in the csv file as a value of delimiter
    for row in csv_rows: 
        print(row)
# Out:
# ['no,fruit,amount']
# ['1,Banana,4 lb']
# ['2,Orange,5 lb']
# ['3,Apple,2 lb']
# ['4,Strawberry,6 lb']
# ['5,Cherry,3 lb']

# %%
with open("annual_assesment.csv", 'r', encoding="utf-8") as file:
   print(file.read())
