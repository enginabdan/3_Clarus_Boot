# %%
# 7_Python+_Ders_7_Scripts&Modules_Initialization_09_06_2021

# %%
# Creating and Working with Modules

# %%
# Scripts & Modules Initialization

# %%
# Scripts and modules have essentially identical structures in terms of creation and are the files with a .py extension, containing some Python codes, statements, operations, and functions.

# %%
# When using Jupyter Lab / Notebook, you will almost always work with files with a .ipynb extension.

# %%
# With Visual Studio Code we use .py as Python Idle

# %%
from module import my_function_1
from module import my_function_2

area = my_function_1(10, 20)
hypotenuse = my_function_2(30, 40)
print(area)
print(hypotenuse)
# Out:
# 200
# 50.0

# %%
# Working with the Modules (Optional)

# %%
# As you see, when you want to import this file as a module, it acts as a script for the first importing, which is undesirable. Example >>> import module >>> will seen only the output of the script

# %%
import my_module
area_rect = my_module.my_function_1(5, 10)
hyp = my_module.my_function_2(3, 4)
print("area : {}, hypotenues : {}".format(area_rect, hyp))
# Out:
# area : 50, hypotenues : 5.0

# %%
from area import my_function_1
area_1 = my_function_1(3, 4)
area_2 = my_function_1(5, 6)
area_3 = my_function_1(6, 8)
print(area_1)
print(area_2)
print(area_3)
# Out:
# 12
# 30
# 48

# %%
from hypotenues import my_function_2
hypotenuse_1 = my_function_2(3, 4)
hypotenuse_2 = my_function_2(6, 8)
hypotenuse_3 = my_function_2(9, 12)
print(hypotenuse_1)
print(hypotenuse_2)
print(hypotenuse_3)
# Out:
# 5.0
# 10.0
# 15.0
