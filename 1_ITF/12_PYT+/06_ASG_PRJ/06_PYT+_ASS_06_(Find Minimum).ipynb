# %%
# 06_PYT+_ASS_06_(Find Minimum)

# %% [markdown]
# Problem :
#
#     1. Define a function named my_min to find the min of the inputted numbers.

# %%
def my_min(*data):
  s = data[0]
  for num in data:
    if num < s:
      s = num
  return s

print(my_min(5,6,7))
# Out:
# 5
