# %%
# 01_PYT+_ASS_01_(Doubler)

# %% [markdown]
# Problem :
#
#     1. Given two integer values, return their sum.
#     2. If the two values are the same, then return double their sum.

# %%
def sum_double(x, y) :
    if x != y :
        return x + y
    else :
        return (x + y) * 2
print(sum_double(1, 2))
# Out:
# 3
