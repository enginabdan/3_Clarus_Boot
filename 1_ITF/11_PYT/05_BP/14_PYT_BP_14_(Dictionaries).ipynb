# %%
# 14_Python_Ders_14_30_04_2021_Bireysel_Calısma

# %%
# 4. Bölüm 4. Kısım (Tuples)

# %%
# ----------------Dictionaries----------------

# %%
# collection types which store item pairs.
# It contains words and their meanings
# words as key and the meaning of the words as value.
# key-value pairs called items
# curly braces 👉🏻{}
# enclosing pairs, separated by commas, in curly-braces

# %%
empty_dict_1 = {}       # Burada {"animal":"dog", "color":"red"} olarak.
empty_dict_2 = dict()   # # Burada {animal = "dog", color = "red"} olarak.

# %%
empty_dict_1 = {
    "animal":"dog",
    "color":"red"
}
empty_dict_2 = dict(animal = "dog", color = "red")

# %%
empty_dict_1 = {}
print(type(empty_dict_1))
# Out:
# <class 'dict'>

# %%
my_dict = {'key1': 'value1',
            'key2': 'value2',
            'key3': 'value3'
            }

# %%
state_capitals = {'Arkansas': 'Little Rock',
                  'Colorado': 'Denver',
                  'California': 'Sacramento',
                  'Georgia': 'Atlanta' 
                 }
print(state_capitals['Colorado']) # accessing method
# Out:
# Denver

# %%
state_capitals = {'Arkansas': 'Little Rock',
                  'Colorado': 'Denver',
                  'California': 'Sacramento',
                  'Georgia': 'Atlanta' 
                 }
state_capitals['Virginia'] = 'Richmond' # adding a new item
print(state_capitals)
# Out:
# {'Arkansas': 'Little Rock', 'Colorado': 'Denver', 'California': 'Sacramento', 'Georgia': 'Atlanta', 'Virginia': 'Richmond'}

# %%
mix_values = {'animal': ('dog', 'cat'),  # tuple type
              'planet': ['Neptun', 'Saturn', 'Jupiter'],  # list type
              'number': 40,  # int type
              'pi': 3.14,  # float type
              'is_good': True}  # bool type

mix_keys = {22 : "integer",
            1.2 : "float",
            True : "boolean",
            "key" : "string"}

# %%
dict_by_dict = dict(animal='dog', planet='neptun', number=40, pi=3.14, is_good=True)
print(dict_by_dict)
# Out:
# {'animal': 'dog', 'planet': 'neptun', 'number': 40, 'pi': 3.14, 'is_good': True}

# %%
dict_by_dict = {'animal': 'dog',
                'planet': 'neptun',
                'number': 40,
                'pi': 3.14,
                'is_good': True}

print(dict_by_dict.items(), '\n')
print(dict_by_dict.keys(), '\n')
print(dict_by_dict.values())
# Out:
# dict_items([('animal', 'dog'), ('planet', 'neptun'), ('number', 40), ('pi', 3.14), ('is_good', True)])
#
# dict_keys(['animal', 'planet', 'number', 'pi', 'is_good'])
#
# dict_values(['dog', 'neptun', 40, 3.14, True])

# %%
dict_by_dict = {'animal': 'dog',
                'planet': 'neptun',
                'number': 40,
                'pi': 3.14,
                'is_good': True}
dict_by_dict.update({'is_bad': False})  # dict_by_dict["is_bad"] = "False" yapabilirsin
print(dict_by_dict)
# Out:
# {'animal': 'dog', 'planet': 'neptun', 'number': 40, 'pi': 3.14, 'is_good': True, 'is_bad': False}

# %%
dict_by_dict = {'animal': 'dog',
               'planet': 'neptun',
               'number': 40,
               'pi': 3.14,
               'is_good': True,
               'is_bad': False}

del dict_by_dict['animal']
print(dict_by_dict)
# Out:
# {'planet': 'neptun', 'number': 40, 'pi': 3.14, 'is_good': True, 'is_bad': False}

# %%
# you can check if the key is in the dictionary.
# in operator; if the key is in dictionary, will be True otherwise False
# not in operator; if the key is not in dictionary, will be True otherwise False

# %%
dict_by_dict = {'planet': 'neptun',
               'number': 40,
               'pi': 3.14,
               'is_good': True,
               'is_bad': False}

print('pi' in dict_by_dict) 
print('animal' not in dict_by_dict)  # remember, we have deleted 'animal'
# Out:
# True
# True

# %%
school_records={
    "personal_info":
        {"kid":{"tom": {"class": "intermediate", "age": 10},
                "sue": {"class": "elementary", "age": 8}
               },
         "teen":{"joseph":{"class": "college", "age": 19},
                 "marry":{"class": "high school", "age": 16}
               },               
        },
        
    "grades_info":
        {"kid":{"tom": {"math": 88, "speech": 69},
                "sue": {"math": 90, "speech": 81}
               },
         "teen":{"joseph":{"coding": 80, "math": 89},
                 "marry":{"coding": 70, "math": 96}
               },               
        },        
}

# %%
school_records={
    "personal_info":
        {"kid":{"tom": {"class":"intermediate", "age":10},
                "sue": {"class":"elementary", "age":8}
               },
         "teen":{"joseph":{"class":"college", "age":19},
                 "marry":{"class":"high school", "age":16}
               },               
        },
}

print(school_records['personal_info']['teen']['marry']['age'])
# Out:
# 16
