# %%
# 01_PYT_BP_06_(Basic_Data_Types)

# %%
# Note that, we assign value to a variable using 👉 =

# %%
# We will now discuss some simple data types commonly used in Python:
# String,
# Signed Integer,
# Floating Point,
# Complex,
# Boolean.

# %%
# STRINGS

# %%
text1 = "I have learned strings" # surrounded with double quotes
print(text1)
# Out:
# I have learned strings

# %%
e_mail = 'joseph@clarusway.com' # surrounded with single quotes
print(e_mail)
# Out:
# joseph@clarusway.com

# %%
print('632') # this is also a string type
# Out:
# 632

# %%
text = "I'm string type"
print(text)
# Out:
# I'm string type

# %%
# NUMERIC TYPES

# %%
# Signed Integer type is called int (72, -125, 0)

# %%
# Floating point type is called float (72.4, -125.6, 0.0)

# %%
# Complex type is called complex (3.14j)

# %%
# Integers : they are whole numbers (positive, negative or zero), including no decimal point.
# Floats : they stand for real numbers with a decimal point.
# Complexes : they are written in the form, x + yj , where x is the real part and y is the imaginary part.

# %%
# BOOLEAN

# %%
# Boolean types are called bool
# Their values are the two constant objects False and True.

# %%
tv_open = True  # it seems TV is on now

# %%
is_rainy = False  # I love sunny weather

# %%
# TYPE CONVERSION

# %%
# str() converts to string type
# int() converts to signed integer type
# float() converts to floating point type

# %%
example1 = 'sometimes what you say is less important than how you say it'
print(type(example1))
# Out:
# <class 'str'>

# %%
example2 = '71'
print(type(example2))
# Out:
# <class 'str'>

# %%
example3 = 71
print(type(example3))
# Out:
# <class 'int'>

# %%
example4 = 71.0
print(type(example4))
# Out:
# <class 'float'>

# %%
example5 = 3.14j
print(type(example5))
# Out:
# <class 'complex'>

# %%
example6 = True
print(type(example6))
# Out:
# <class 'bool'>

# %%
# Note that we write the first letter of True in uppercase.
# This is the rule of Python that we must write like this : True, False.

# %%
f = 3.14  # the type is float
print(type(f))
# Out:
# <class 'float'>

# %%
f = 3.14  # the type is float
s = str(f)  # converting float to string
print(type(s))
# Out:
# <class 'str'>

# %%
f = 3.14  # the type is float
i = int(f)  # while converting a float value to an integer its decimal part is disregarded
print(i, '\n')
print(type(i))
# Out:
# 3
#
# <class 'int'>

# %%
i = 3
f = float(i)
print(f, '\n')
print(type(f))
# Out:
# 3.0
#
# <class 'float'>

# %%
x = 39
v = "11"
y = "2.5"
z = "I am at_"

print(x-int(v)) # 39-11 v'yi önce int yaptı, normalde str.
print(x-float(y)) # 39-2.5 y'yi önce float yaptı, normalde str.
print(z+str(x))  # Concatenate yaptı, x normalde int, str yaptı.
# Out:
# 28
# 36.5
# I am at_39

# %%
a = 10
print(type(str(a)))
# Out:
# <class 'str'>

# %%
a = "merhaba"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 36.5
b = '30'
c = '3.5'
d = ' F is enough for room temperature.'  # F'nin önünde bir boşluk vat, concatenate yaptı.
print(str(a+int(b)+float(c))+d)  # float sonuç yazmalı.
# Out:
# 70.0 F is enough for room temperature.

# %%
# VARIBLES

# %%
# Creating, naming the variable and assigning a value to it happen simultaneously by this syntax :
# ball_box = 20 basketball balls

# %%
color = 'red'  # str type variable
season = 'summer'
price = 250  # int type variable
pi = 3.14  # float type variable
color = 'blue'  # You can always assign a new value to a created variable
price = 100  # value of 'price' is changed
season = 'winter'  

print(color, price, season, sep=', ')
# Out:
# blue, 100, winter

# %%
a = 5
b = 55
c = 555
c = a
b = c
a = b

print(a, b, c, sep=', ')
# Out:
# 5, 5, 5

# %%
n = "2020"
print(type(n))
# Out:
# <class 'str'>

# %%
x = 60
y = 6
z = 10
z=y
y=x
x=z
print (x, y, z, sep = "-")
# Out:
# 6-60-6
