# %%
# 01_PYT_BP_02_(First_Step_Coding)

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Engin")
# Out:
# Engin

# %%
print('Merhaba')
# Out:
# Merhaba

# %%
print('being a good person')
# Out:
# being a good person

# %%
print('Merhaba')
# Out:
# Merhaba

# %%
print("Merhaba')
# Out:
#   File "<ipython-input-6-6ec735278480>", line 1
#     print("Merhaba')
#                     ^
# SyntaxError: EOL while scanning string literal

# %%
print('''Merhaba''')
# Out:
# Merhaba

# %%
print("""Merhaba""")
# Out:
# Merhaba

# %%
print("It's my pleasure!")
# Out:
# It's my pleasure!

# %%
print('He said: "I am done" and fell down.')
# Out:
# He said: "I am done" and fell down.

# %%
print("it's not a problem")
# Out:
# it's not a problem

# %%
print('''it's not a problem using "triple" quotes''')
# Out:
# it's not a problem using "triple" quotes

# %%
print('We should have enough time for our family")
# Out:
#   File "<ipython-input-18-67ff08d8253d>", line 1
#     print('We should have enough time for our family")
#                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
print(572)
# Out:
# 572

# %%
print(3.14)
# Out:
# 3.14

# %%
print('3.14')
# Out:
# 3.14

# %%
print('no pain')
print('no gain')
print(3.14)
# Out:
# no pain
# no gain
# 3.14

# %%
print('first line')
print()  # second line is empty
print('third line')
# Out:
# first line
#
# third line

# %%
print("It's my plesure")
# Out:
# It's my plesure
