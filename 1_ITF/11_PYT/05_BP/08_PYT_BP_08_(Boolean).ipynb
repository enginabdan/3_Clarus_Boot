# %%
# 01_PYT_BP_08_(Boolean)

# %%
# Boolean Priorities
# NOT
# AND
# OR

# %%
# NOT = True  False
# None, 0, 0.0, 0.j, " ", [], {} = Falseth
# Others Truthy

# %%
# AND looks to FALSE, the firt left, all TRUE than get the last, right TRUE
# OR looks to TRUE, the first left, all FALSE than get the last, right FALSE

# %%
logic = True and False or not False or False
print(logic)
# Out:
# True

# %%
logic = True and False or 1 or not False or False
print(logic)
# Out:
# 1

# %%
print(2 and 3)
# Out:
# 3

# %%
print(2 and 3 or False)
# Out:
# 3

# %%
print(False or 2 and 3)
# Out:
# 3

# %%
print(False and 2 and 3)
# Out:
# False

# %%
print(1 and 0)
# Out:
# 0

# %%
print(1 and "I am doing good!")
# Out:
# I am doing good!

# %%
print([] and "Hello World!")
# Out:
# []

# %%
print(2 or 3)
# Out:
# 2

# %%
print(None or 1)
# Out:
# 1

# %%
print(0 or {})
# Out:
# {}

# %%
print([] or "Hello World!")
# Out:
# Hello World!
