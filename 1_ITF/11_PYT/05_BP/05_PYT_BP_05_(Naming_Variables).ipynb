# %%
# 01_PYT_BP_05_(Naming_Variables)

# %%
# Choose lowercase words and use underscore to split the words:
# price = [22, 44, 66],
# low_price = 12.00

# %%
# Do not use the characters; 
# 'l' (lowercase letter el),
# 'O' (uppercase letter oh),
# 'I' (uppercase letter eye) as single-character variable names.
# In some fonts, these characters are indistinguishable from the numerals one and zero.
# If you want to use 'l', use 'L' instead.
# l = 'It is not correct use',
# O = "It's also incorrect use"

# %%
# Do not use specific Python keywords as a name,
# like sum, max, min, in, or, for

# %%
# Use a sensible name.
# figures = 'this is better',
# f = 'it is not meaningful'

# %%
# Don't choose too common names.
# Use a name to describe the meaning of the variable.
# However, try to limit it to no more than 3 words.
