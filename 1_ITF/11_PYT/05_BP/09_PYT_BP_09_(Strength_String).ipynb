# %%
# 01_PYT_BP_09_(Strength_String)

# %%
fruit = 'Orange'

print('Word                   : ' , fruit)
print('First letter           : ' , fruit[0])
print('Second letter          : ' , fruit[1])
print("3rd to 5th letters     : " , fruit[2:5])
print("Letter all after 3rd   : " , fruit[2:])
# Out:
# Word                   :  Orange
# First letter           :  O
# Second letter          :  r
# 3rd to 5th letters     :  ang
# Letter all after 3rd   :  ange

# %%
print("Orange"[2])
# Out:
# a

# %%
fruit = "Orange"
print(fruit[2])
# Out:
# a

# %%
print("Orange"[2:5])
# Out:
# ang

# %%
fruit = "Orange"
print(fruit[2:5:2])
# Out:
# ag

# %%
fruit = "Orange"
print(fruit[-1:0:-2])
# Out:
# enr

# %%
city = 'Phoenix'

print(city[1:])  # starts from index 1 to the end
print(city[:6])  # starts from zero to 5th index
print(city[::2])  # starts from zero to end by 2 step
print(city[1::2])  # starts from index 1 to the end by 2 step
print(city[-3:])  # starts from index -3 to the end
print(city[::-1])  # negative step starts from the end to zero
# Out:
# hoenix
# Phoeni
# Ponx
# hei
# nix
# xineohP

# %%
# ----------------len(fruit)-----------------

# %%
fruit = "Orange"
print(len(fruit))
# Out:
# 6

# %%
print(len("Orange"))
# Out:
# 6

# %%
print(len("Orange is"))
# Out:
# 9

# %%
vegetable = 'Tomato'

print('length of the word', vegetable, 'is :', len(vegetable))
# Out:
# length of the word Tomato is : 6

# %%
vegetable = 'Tomato'

print('length of the word', vegetable, 'is :', len("Tomato"), "and the type of ", vegetable, "is", type(vegetable), sep="\n")
# Out:
# length of the word
# Tomato
# is :
# 6
# and the type of
# Tomato
# is
# <class 'str'>

# %%
print('length of the word', vegetable, 'is :', len("Tomato"), "\n")
# Out:
# length of the word Tomato is : 6

# %%
print('length of the word', vegetable, 'is :', len("Tomato"), "\t")
# Out:
# length of the word Tomato is : 6

# %%
# ---------------------processing and using string data-----------------
# Arithmetic syntax (+, *, and =),
# % operator formatting,
# string.format() method,
# f-string formatting.

# %%
print('clarus' + 'way') # This is an Concatanate
# Out:
# clarusway

# %%
print(3*'no way!')
# Out:
# no way!no way!no way!

# %%
print("Engin", "ABDAN", sep="\n")
# Out:
# Engin
# ABDAN

# %%
fruit = 'Orange'
vegetable = 'Tomato'
print("using + :", fruit + vegetable)
print("using * :", 3 * fruit)
# Out:
# using + : OrangeTomato
# using * : OrangeOrangeOrange

# %%
fruit = 'orange'
fruit += ' apple'
print(fruit)
# Out:
# orange apple

# %%
fruit = 'orange'
fruit += ' apple'
fruit += ' banana'
fruit += ' apricot'
print(fruit)
# Out:
# orange apple banana apricot

# %%
fruit1 = "Apple"
fruit2 = "Orange"
print(2*fruit1, 3*fruit2)
# Out:
# AppleApple OrangeOrangeOrange

# %%
# ---------------------String Formatting with '%' Operator-----------------

# %%
# %s---%11s------ String---Stringin ilk 11 karakterini al
# %d---%(fruit)d- Decimal--Variableın değerini decimal al
# %2f------------ Float----Sayının sonuna . sonrası 2 sıfır ekle

# %%
phrase = 'I have %d %s and %.2f brothers' % (4, "children", 5)  
print (phrase)
# Out:
# I have 4 children and 5.00 brothers

# %%
print('I have %d %s and %.2f brothers' % (4, "children", 5))
# Out:
# I have 4 children and 5.00 brothers

# %%
text = "children"
phrase = 'I have %d %s and %.2f brothers' % (4, text, 5)  
print (phrase)
# Out:
# I have 4 children and 5.00 brothers

# %%
text = "children"
print('I have %d %s and %.2f brothers' % (4, text,  5.5))
# Out:
# I have 4 children and 5.50 brothers

# %%
sentence = "apologizing is a virtue"
print("%.11s" % sentence)  # we get first 11 characters of the string
# Out:
# apologizing

# %%
text = "Senden daha güzel."
print("%.11s" % text)
# Out:
# Senden daha

# %%
x = "HelloWorld!"
print('%.5s' % x)
# Out:
# Hello

# %%
# # ---------------------String Formatting with 'string.format()' Method-----------------

# %%
fruit = 'Orange'
vegetable = 'Tomato'
amount = 4
print('The amount of {} we bought is {} pounds'.format(fruit, amount))
# Out:
# The amount of Orange we bought is 4 pounds

# %%
a = "elma"
b = "soğan"
c = "3"
d = "5"
print("Ben pazardan, {} kg {} {} kg {} aldım.".format(c, a, d, b))
# Out:
# Ben pazardan, 3 kg elma 5 kg soğan aldım.

# %%
print('{state} is the most {adjective} state of the {country}'.format(state='California', country='USA', adjective='crowded'))
# Out:
# California is the most crowded state of the USA

# %%
print("{ülke}'nin en {sıfat} zirvesi {dağ}'dır.".format(dağ="Ağrı Dağı", ülke="Türkiye", sıfat="yüksek"))
# Out:
# Türkiye'nin en yüksek zirvesi Ağrı Dağı'dır.

# %%
dağ = "Ağrı Dağı"
print("{ülke}'nin en {sıfat} zirvesi {}'dır.".format(sıfat="yüksek", ülke="Türkiye", dağ))
# Out:
#   File "<ipython-input-92-00ebee5198f0>", line 2
#     print("{ülke}'nin en {sıfat} zirvesi {}'dır.".format(sıfat="yüksek", ülke="Türkiye", dağ))
#
# ^
# SyntaxError: positional argument follows keyword argument

# %%
print("{}'nin en {sıfat} zirvesi {dağ}'dır.".format("Türkiye", dağ = "Ağrı Dağı", sıfat="yüksek"))
# Out:
# Türkiye'nin en yüksek zirvesi Ağrı Dağı'dır.

# %%
print("{0}'nin en {sıfat} zirvesi {dağ}'dır.".format("Türkiye", dağ = "Ağrı Dağı", sıfat="yüksek"))
# Out:
# Türkiye'nin en yüksek zirvesi Ağrı Dağı'dır.

# %%
ülke = "Türkiye"
print("{}'nin en {sıfat} zirvesi {dağ}'dır.".format(ülke, dağ = "Ağrı Dağı", sıfat="yüksek"))
# Out:
# Türkiye'nin en yüksek zirvesi Ağrı Dağı'dır.

# %%
print('{0} is the most {adjective} state of the {country}'.format('California', country='USA', adjective='crowded'))
# Out:
# California is the most crowded state of the USA

# %%
print("{6} {0} {5} {3} {4} {1} {2}".format('have', 6, 'months.', 'a job', 'in', 'found', 'I will'))
# Out:
# I will have found a job in 6 months.

# %%
# !!!!!!!!! Be careful not to write keyword arguments before positional arguments.

# %%
# ---------------------String Formatting with 'f-string' Method-----------------

# %%
fruit = 'Orange'
vegetable = 'Tomato'
amount = 6
output = f"The amount of {fruit} and {vegetable} we bought are totally {amount} pounds"
print(output)
# Out:
# The amount of Orange and Tomato we bought are totally 6 pounds

# %%
fruit = 'Orange'
vegetable = 'Tomato'
amount = 6
print(f"The amount of {fruit} and {vegetable} we bought are totally {amount} pounds")
# Out:
# The amount of Orange and Tomato we bought are totally 6 pounds

# %%
result = f"{4 * 5}"  # çarpma işlemi yapılır, sonucu str olarak yazdırılır.
print(result)
print(type(result))
# Out:
# 20
# <class 'str'>

# %%
my_name = 'JOSEPH'
output = f"My name is {my_name.capitalize()}."
print(output)
# Out:
# My name is Joseph.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = (                       # Burada al alta yazabilmek için ya ( kullanacağız veya \ kullanacağız.
     f"Hi {name}. "
     f"You are one of the {job} "
     f"in the {domain} section."
)
print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = f"Hi {name}. " \
     f"You are one of the {job} " \
     f"in the {domain} section."

print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = (f"Hi {name}. " f"You are one of the {job} " f"in the {domain} section.")
print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = f"Hi {name}. " f"You are one of the {job} " f"in the {domain} section."
print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
print(f"Hi {name}. " f"You are one of the {job} " f"in the {domain} section.")
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.
