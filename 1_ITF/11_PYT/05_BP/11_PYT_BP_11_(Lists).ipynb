# %%
# 01_PYT_BP_11_(Lists)

# %%
# 4. Bölüm 1. Kısım (Main String Operations)

# %%
# collection types hold multiple values.

# %%
# ----------------List----------------

# %%
# list are not limited to a single data type
# mixed_list = [11, 'Joseph', False, 3.14, None, [1, 2, 3]]

# %%
# a = "sfvsssdgv"
# b = list(a)
# c = [a]
# print(b)
# print(c)

# %%
a = ["b", "c", "d", "e"]
print(a)
# Out:
# ['b', 'c', 'd', 'e']

# %%
print("Engin"[0::2]) # Aradaki farkı görmek açısından yazdırdım.
# Out:
# Egn

# %%
country = "Turkey" # Aradaki farkı görmek açısından yazdırdım.
print(country)
# Out:
# Turkey

# %%
print("Turkey" "USA") # Aradaki farkı görmek açısından yazdırdım.
# Out:
# TurkeyUSA

# %%
country = "Turkey", "USA" # Aradaki farkı görmek açısından yazdırdım.
print(country)
# Out:
# ('Turkey', 'USA')

# %%
country = ["USA", "Brasil", "UK", "Germany", "Turkey", "New Zealand"]

# %%
country = ["USA", "Brasil", "UK", "Germany", "Turkey", "New Zealand"]
print(country)
# Out:
# ['USA', 'Brasil', 'UK', 'Germany', 'Turkey', 'New Zealand']

# %%
a = "I quit smoking"
b = list(a)
print(b)
c= [a]
print(c)
# Out:
# ['I', ' ', 'q', 'u', 'i', 't', ' ', 's', 'm', 'o', 'k', 'i', 'n', 'g']
# ['I quit smoking']

# %%
a = "I quit smoking"  # Yukarıdaki ile aynı
print(list(a))
print([a])
# Out:
# ['I', ' ', 'q', 'u', 'i', 't', ' ', 's', 'm', 'o', 'k', 'i', 'n', 'g']
# ['I quit smoking']

# %%
a = [11, 'Joseph', False, 3.14, None, [1, 2, 3]]
b = list(a)
c = [a]
print(b)
print(c)
# Out:
# [11, 'Joseph', False, 3.14, None, [1, 2, 3]]
# [[11, 'Joseph', False, 3.14, None, [1, 2, 3]]]

# %%
warning = 'You must quit smoking!'
print(len(warning))
print(list(warning))
print([warning])
print(len(list(warning)))
# Out:
# 22
# ['Y', 'o', 'u', ' ', 'm', 'u', 's', 't', ' ', 'q', 'u', 'i', 't', ' ', 's', 'm', 'o', 'k', 'i', 'n', 'g', '!']
# ['You must quit smoking!']
# 22

# %%
a = [] # we'll have to make an empty list to fill it later with the data you want
b = list(a)
c = [a]
print(b)
print(c)
# Out:
# []
# [[]]

# %%
a = [1,2,3]   # a.append()
# print(a.append(4)) # Bu tarz bir kısa yazım tarzı yok!!!
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [1,2,3]     # a.insert()
# print(a.insert(2,4)) # Bu tarz bir kısa yazım tarzı yok!!!
a.insert(2, 4)
print(a)
# Out:
# [1, 2, 4, 3]

# %%
a = [1,2,3]    # a[1] = 23
a[1] = 4       # Burada ise 1nci yere atanan 2 yerine 4 yazdırdı listede.
print(a)
# Out:
# [1, 4, 3]

# %%
a = [1,2,3]    # a.remove(1)
# print(a.remove(2)) # Bu tarz bir kısa yazım tarzı yok!!!
a.remove(2)
print(a)
# Out:
# [1, 3]

# %%
a = ["ankara", "izmir", "konya"]    # a.remove("konya")
# print(a.remove("konya")) # Bu tarz bir kısa yazım tarzı yok!!!
a.remove("konya")
print(a)
# Out:
# ['ankara', 'izmir']

# %%
a = ["ankara", "izmir", "konya"]
print(a.sort()) # Bu tarz bir kısa yazım tarzı yok!!!
a.sort()
print(a)
# Out:
# None
# ['ankara', 'izmir', 'konya']

# %%
a = [2,3,1]
print(a.sort()) # Bu tarz bir kısa yazım tarzı yok!!!
a.sort()
print(a)
# Out:
# None
# [1, 2, 3]

# %%
a = [2,3,1]
b = ["ankara", "izmir", "konya"]
print(len(a))
print(len(b))
# Out:
# 3
# 3

# %%
a = [2,3,1]
print(a*3)
# Out:
# [2, 3, 1, 2, 3, 1, 2, 3, 1]

# %%
empty_list_1 = []
empty_list_1.append('114')
empty_list_1.append('plastic-free sea')
print(empty_list_1)
# Out:
# ['114', 'plastic-free sea']

# %%
city = ['New York', 'London', 'Istanbul', 'Seoul', 'Sydney']
city.append('Addis Ababa')
print(city)
# Out:
# ['New York', 'London', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']

# %%
city = ['New York', 'London', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']
city.insert(2, 'Stockholm')
print(city)
# Out:
# ['New York', 'London', 'Stockholm', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']

# %%
city = ['New York', 'London', 'Stockholm', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']
city.remove('London')
print(city)  # we have deleted 'London'
# Out:
# ['New York', 'Stockholm', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']

# %%
city = ['New York', 'Stockholm', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']
city.sort()  # lists the items in alphabetical order
print(city)
# Out:
# ['Addis Ababa', 'Istanbul', 'New York', 'Seoul', 'Stockholm', 'Sydney']

# %%
city = ['Addis Ababa', 'Istanbul', 'New York', 'Seoul', 'Stockholm', 'Sydney']
print(len(city))
# Out:
# 6

# %%
my_list = [1, 3, 5, 7]
print(my_list * 3)
# Out:
# [1, 3, 5, 7, 1, 3, 5, 7, 1, 3, 5, 7]

# %%
city = ['New York', 'Stockholm', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']
city[1] = 'Melbourne'  # we assign 'Melbourne' to index 1
print(city)
# Out:
# ['New York', 'Melbourne', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']

# %%
a = [1,2,3]
print(a.index(2))
print(a.index(1))
print(a.index(3))
# Out:
# 1
# 0
# 2

# %%
a = [1,2,3,4,5,6,7,8,9]
del a[::2]    # a Listesinde baştan sona kadar birer atlayarak silerek git 
print(a)
# Out:
# [2, 4, 6, 8]

# %%
a = [1,2,3,4,5,6,7,8,9] # index noyu, boş ise sondaki indexi siler
a.pop(3)
print(a)
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9]

# %%
a = [1,2,3,4,5,6]
b = []
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for x in a:
  if x%2 != 0:
    b.append(x**2)
print(b)
# Out:
# [1, 9, 25]

# %%
print([x**2 for x in a if x%2 !=0])
# Out:
# [1, 9, 25]
