# %%
# 01_PYT_BD_07

# %%
# -----------Simple_Operations--------------

# %%
# Arithmetic
# print
# Escape Squences

# %%
# + addition
# - subtraction
# * exponentiation
# / Division
# //  Floor Division
# %   Modulus

# %%
# 100 + 45 = 145
# 500 - 65 = 435
# 4 * 5 = 20
# 10 / 2 = 5.0
# 11 // 2 = 5
# 5 ** 3 = 125
# 10 % 3 = 1

# %%
29 // 3
# Out:
# 9

# %%
29 / 3
# Out:
# 9.666666666666666

# %%
14 % 2
# Out:
# 0

# %%
print(11-7)
print(4 + 11.0)
print("11-7")
print("4" + 4)
# Out:
# 4
# 15.0
# 11-7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a1b95adfb0ed> in <module>()
#       2 print(4 + 11.0)
#       3 print("11-7")
# ----> 4 print("4" + 4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
num1, num2 = 81, 55
num3 = num1 - num2
print(num3)
# Out:
# 26

# %%
r = 5
pi = 3.14
area = pi * r**2
print(area)
# Out:
# 78.5

# %%
r = 5
pi = 3.14
perimeter = 2 * pi * r
print(perimeter)
# Out:
# 31.400000000000002

# %%
print(11 % 2)
print((4*5) / 2)
# Out:
# 1
# 10.0

# %%
print(2 ** 3)
print(3 ** 2)
a = 2
b = 8
print((a * b) ** 0.5)  # Bir sayının karekökü hep floattur
# Out:
# 8
# 9
# 4.0

# %%
x = 0
x = x + 1
print(x)
# Out:
# 1

# %%
x = x + 1
print(x)
# Out:
# 2

# %%
x = 5
x += 1
print(x)
# Out:
# 6

# %%
c = 3
c = c * 2
print(c)
# Out:
# 6

# %%
c = c * 2
print(c)
# Out:
# 12

# %%
c *= 2
print(c)
# Out:
# 24

# %%
# parentheses ()
# power **
# unary minus  -3
# multiplication and division *  /
# addition and subtraction +  -

# %%
a = (1 + 3) ** (2 ** (1 * 2 / 2) / 2)
print(a)
# Out:
# 4.0

# %%
a = 3   # hypotenuse of the triangle
b = 4
c = (3 ** 2 + 4 ** 2) ** 0.5
print(c)
# Out:
# 5.0

# %%
# ----------Operations with print Function-------------

# %%
print(3,4,5, "istanbul", False, "3+2")
# Out:
# 3 4 5 istanbul False 3+2

# %%
a,b,c,d,e = 3,4,5, "istanbul", False
print(a,b,c,d,e)
# Out:
# 3 4 5 istanbul False

# %%
number = 2020
text = "We have reached"
print(text, number)
# Out:
# We have reached 2020

# %%
# sep=""
# end="\n"

# %%
print("engin", "azra", "neda", "aden")
# Out:
# engin azra neda aden

# %%
print("engin", "azra", "neda", "aden", sep="-")
# Out:
# engin-azra-neda-aden

# %%
print("engin", "azra", "neda", "aden", sep="**")
# Out:
# engin**azra**neda**aden

# %%
print("engin", "azra", "neda", "aden", sep="\n")
# Normalde yanyana olanlar default , ile araya boşluk koyar
# Burada sep=" " defaulttur.
# Default yerine de başka birşey koyabilirsiniz.
# Out:
# engin
# azra
# neda
# aden

# %%
print("engin", "azra", "neda", "aden", "\n")
# Out:
# engin azra neda aden

# %%
print("engin", "azra", "neda", "aden", end="\n")
# Out:
# engin azra neda aden

# %%
print("engin")
print("azra")
print("neda")
print("aden")
# Out:
# engin
# azra
# neda
# aden

# %%
print("engin", end="-")
print("azra", end=" ")
print("neda") # Normalde default print sonu newlinedır "\n"
print("aden") # end="" ile bunu değiştirebilirlsin
# Out:
# engin-azra neda
# aden

# %%
print("engin")
print("azra")
print("neda")
print("aden")
# Out:
# engin
# azra
# neda
# aden

# %%
text1 = "I bought"
text2 = "kg. of apple this morning"
amount = 6
text3 = text1 + " " + str(amount) + " " + text2  # concatenate
print(text1, amount, text2)
print("I bought", 6, "kg. of apple this morning")
print("I bought", "6", "kg. of apple this morning") 
print(text3)
# Out:
# I bought 6 kg. of apple this morning
# I bought 6 kg. of apple this morning
# I bought 6 kg. of apple this morning
# I bought 6 kg. of apple this morning

# %%
"engin"+"azra"
# Out:
# 'enginazra'

# %%
"engin "+"azra"
# Out:
# 'engin azra'

# %%
"engin "+" azra"
# Out:
# 'engin  azra'

# %%
"engin"  +  "azra"
# Out:
# 'enginazra'

# %%
# \n new line
# \t tab mark
# \b backspace

# %%
print(""")
# Out:
#   File "<ipython-input-25-3f29872ceae9>", line 1
#     print(""")
#               ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
print("\"")
# Out:
# "

# %%
print("\")
# Out:
#   File "<ipython-input-27-dff1232de400>", line 1
#     print("\")
#               ^
# SyntaxError: EOL while scanning string literal

# %%
print("3\2=1.5")
# Out:
# 3=1.5

# %%
print("3\\2=1.5")
# Out:
# 3\2=1.5

# %%
print("C:\\south pole\neetle_sharks.txt")
print("...........")
print("first", "fifth", "third", sep="\t")
# Out:
# C:\south pole
# eetle_sharks.txt
# ...........
# first	fifth	third

# %%
print("engin", "\azra", "neda", "\aden")
print('it\'s engin to azra nedan\'s aden in hakan Gülten')
# üstte tek tırnaktan hata verirdi ancak \ "'" özelliğini aldı.
# Out:
# engin zra neda den
# it's engin to azra nedan's aden in hakan Gülten
