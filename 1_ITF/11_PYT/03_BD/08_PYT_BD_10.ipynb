# %%
# 03_PYT_BD_10

# %%
# -----------Main String Operations--------------

# %%
# Changing a Strint

# %%
a = "Engin azra ile evli Olup \
Neda ve aden adlı ve iki Kız ve Çocuğuna sahiptir"
print(a.replace("ve", "veya"))
# Out:
# Engin azra ile evli Olup Neda veya aden adlı veya iki Kız veya Çocuğuna sahiptir

# %%
a = "Engin azra ile evli Olup \
Neda ve aden adlı ve iki Kız ve Çocuğuna sahiptir"
print(a.swapcase())
# Out:
# eNGIN AZRA ILE EVLI oLUP nEDA VE ADEN ADLI VE IKI kIZ VE çOCUĞUNA SAHIPTIR

# %%
a = "Engin azra ile evli Olup \
Neda ve aden adlı ve iki Kız ve Çocuğuna sahiptir"
print(a.capitalize())
# Out:
# Engin azra ile evli olup neda ve aden adlı ve iki kız ve çocuğuna sahiptir

# %%
a = "Engin azra ile evli Olup \
Neda ve aden adlı ve iki Kız ve Çocuğuna sahiptir"
print(a.upper())
# Out:
# ENGIN AZRA ILE EVLI OLUP NEDA VE ADEN ADLI VE IKI KIZ VE ÇOCUĞUNA SAHIPTIR

# %%
a = "Engin azra ile evli Olup \
Neda ve aden adlı ve iki Kız ve Çocuğuna sahiptir"
print(a.lower())
# Out:
# engin azra ile evli olup neda ve aden adlı ve iki kız ve çocuğuna sahiptir

# %%
a = "Engin azra ile evli Olup \
Neda ve aden adlı ve iki Kız ve Çocuğuna sahiptir"
print(a.title())
# Out:
# Engin Azra Ile Evli Olup Neda Ve Aden Adlı Ve Iki Kız Ve Çocuğuna Sahiptir

# %%
a = "I live and work in Alabama"
print(a.upper())
print(a.lower())
print(a.swapcase())
print(a) # Immutability# note that, source text is unchanged.
# Out:
# I LIVE AND WORK IN ALABAMA
# i live and work in alabama
# i LIVE AND WORK IN aLABAMA
# I live and work in Alabama

# %%
# string.method1().method2().method3() önce 1 ...

# %%
a = "I live and work in AlaBAma"
b = a.title()
print(b)
# Out:
# I Live And Work In Alabama

# %%
a = "I live and work in Alabama"
b = a.replace("i", "+")
print(b)
# Out:
# I l+ve and work +n Alabama

# %%
text = "the better the family, the better the society"
print(text.title())
# Out:
# The Better The Family, The Better The Society

# %%
a = "I live and work in Alabama"
b = a.swapcase()
print(b)
print(b.capitalize())
# Out:
# i LIVE AND WORK IN aLABAMA
# I live and work in alabama

# %%
a = "test cümlesi"
print(a.swapcase())
print("test cümlesi".swapcase())
print(str.swapcase(a))
# Out:
# TEST CÜMLESI
# TEST CÜMLESI
# TEST CÜMLESI

# %%
a = "test cümlesi"
print(a.swapcase().lower().upper())
# Out:
# TEST CÜMLESI

# %%
text = "S0d0me and G0m0re"
print(text.replace("0", "o"))
# Out:
# Sodome and Gomore

# %%
text = "S0d0me and G0m0re"
print(text.replace("0", "o", 1))
# Out:
# Sod0me and G0m0re

# %%
text = "S0d0me and G0m0re"
print(text.replace("0", "o", 2))
# Out:
# Sodome and G0m0re

# %%
text = "S0d0me and G0m0re"
print(text.replace("0", "o", -1))
# Out:
# Sodome and Gomore

# %%
text = "S0d0me and G0m0re"
print(text.replace("S0d0me", "Sodome"[::-2]))
# Out:
# eoo and G0m0re

# %%
text = "S0d0me and G0m0re"
print(text.replace("S0d0me", "Sodome"[-2]))
# Out:
# m and G0m0re

# %%
# Editing a String
# string.strip()
# string.rstrip()
# string.lstrip()

# %%
a = "     engin     "
print(a.strip())
# Out:
# engin

# %%
a = "     engin     "
print(a.rstrip())
# Out:
#      engin

# %%
a = "     engin     "
print(a.lstrip())
# Out:
# engin

# %%
a = "engin"
print(a.strip("en"))
# Out:
# gi

# %%
a = "engin"
print(a.rstrip("en"))
# Out:
# engi

# %%
a = "engin"
print(a.lstrip("en"))
# Out:
# gin

# %%
a = "en engin ne"
print(a.strip("en"))
# Out:
#  engin

# %%
a = "enf engin hne"
print(a.strip("en"))
# Out:
# f engin h

# %%
a = "Interoperability"
print(a.strip("iy"))
# Out:
# Interoperabilit

# %%
a = "interoperability"
print(a.strip("iy"))
# Out:
# nteroperabilit

# %%
a = "interoperability"
print(a.lstrip("in"))
# Out:
# teroperability

# %%
a = "interoperability"
print(a.lstrip("inyt"))
# Out:
# eroperability

# %%
a = "interoperability"
print(a.rstrip("inyt"))
# Out:
# interoperabil

# %%
a = "        başında ve sonunda...     "
print(a)
print(a.strip())
print(a.rstrip())
print(a.lstrip())
# Out:
#         başında ve sonunda...
# başında ve sonunda...
#         başında ve sonunda...
# başında ve sonunda...

# %%
text = "tyou can learn almost everything in pre-classz"
print(text.strip("tz").upper())
# Out:
# YOU CAN LEARN ALMOST EVERYTHING IN PRE-CLASS

# %%
text = "In God wee Trust"
text1 = text[:9]
text2 = text[10:]
print(text1 + text2)
print(text.replace("wee", "We"))
print(text.replace("wee", "We").title())
print(text.replace("e", "", 1).title())
print(text.replace("ee", "e", 1).title())
print(text.replace("ee", "e").title())
# Out:
# In God we Trust
# In God We Trust
# In God We Trust
# In God We Trust
# In God We Trust
# In God We Trust
