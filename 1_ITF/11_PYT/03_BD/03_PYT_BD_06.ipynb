# %%
# 01_PYT_BD_06

# %%
# -----------Basic_Data_Types--------------

# %%
# Variables
# Data Types
# Strings
# Numerics
# Boolean
# Type Conversion

# %%
# variable name = value  >>>>  assigning
# planet = "jupyter"
# price = 140

# %%
x = y = z = "same"
print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %%
january = march = may = july = august = october = december = 31
april = january = september = november = june = 30
february = 28
print(january, february, march, april, may, june,\
      july, august, september, october, november, december)
# Out:
# 30 28 31 30 31 30 31 31 30 31 30 31

# %%
thomas = 33
marry = 28
walter = None
isabella = 46

# %%
website = "engin.com"
print(website)
website = "azra.com"
print(website)
# Out:
# engin.com
# azra.com

# %%
first_number = 100
second_number = first_number
print(second_number)
# Out:
# 100

# %%
x = 15
y = 33
z = x
x = y
print(x)
print(y)
print(z)
# Out:
# 33
# 33
# 15

# %%
x = 11
y = 12
z = 13
x = 14
z = 15
x = 16
print(x, y, z)
# Out:
# 16 12 15

# %%
print(x, "ahmet", z, "dünya", 11)
# Out:
# 16 ahmet 15 dünya 11

# %%
a, b, c = 5, 3.2, "Hello"
print(a)
print(b)
print(c)
# Out:
# 5
# 3.2
# Hello

# %%
a, b, c = 1, "engin", 22, 0
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-91433cc96765> in <module>()
# ----> 1 a, b, c = 1, "engin", 22, 0
#       2 print(a,b,c)
#
# ValueError: too many values to unpack (expected 3)

# %%
a, b, c = 1, "engin"
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-79dc5daa79b2> in <module>()
# ----> 1 a, b, c = 1, "engin"
#       2 print(a,b,c)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
a, b, c = 1, "engin", 22
print(a,b,c)
# Out:
# 1 engin 22

# %%
man = "andrew"
color = "green"
age = 32
pi = 3.14
color = "yellow"
age = 44
man = "joseph"
print(man, age, color)
# Out:
# joseph 44 yellow

# %%
# Data Types
#   "String"  "", '', '''''', """"""
#   İnteger   3
#   Float     3.14
#   Complexes None, 0, 0.0, 3.2j, [], {}
#   Boolean   True, False

# %%
my_text = "engin"
print(my_text)
# Out:
# engin

# %%
new_text = "engin"
print(new_text)
# Out:
# engin

# %%
xx = "123, !% * ahmet serdar"
print(xx)
# Out:
# 123, !% * ahmet serdar

# %%
# iterable: tekrarlanan, elemanlarına teker teker ayrılabilen
# indexlerine ulaşıp elemanlarına, karakterlerine ayrılabilen.

# %%
type(xx)
# Out:
# str

# %%
print(type(xx))
# Out:
# <class 'str'>

# %%
print("engin.com")
print("654")
print(654)
print(type(654))
print("It's okay!")
# Out:
# engin.com
# 654
# 654
# <class 'int'>
# It's okay!

# %%
a = "1923"
b = "%(#&*?-"
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 1923
# %(#&*?-
# <class 'str'>
# <class 'str'>

# %%
a = 40.0
b = -17.65
print(a)
print(b)
print(type(a))
print(type(b))
type(a)
type(b)
# Out:
# 40.0
# -17.65
# <class 'float'>
# <class 'float'>
# float

# %%
## Type Conversion
# int >>> str
# str >>> int
# int >>> float
# float >>> int
# str >>> float
# float >>> str

# %%
a = "I'm engin"
print(type(a))
# Out:
# <class 'str'>

# %%
# str()
# int()
# float()

# %%
print(str(True))
str(True)
# Out:
# True
# 'True'

# %%
pi = 3.14
converted_pi = str(pi)
print(converted_pi)
print(type(converted_pi))
str(pi)
# Out:
# 3.14
# <class 'str'>
# '3.14'

# %%
pi = 3.14
converted_pi = int(pi)
int(3.14)
print(type(converted_pi))
print(converted_pi)
# Out:
# <class 'int'>
# 3

# %%
int("10")
# Out:
# 10

# %%
int("10.4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-b87050daedee> in <module>()
# ----> 1 int("10.4")
#
# ValueError: invalid literal for int() with base 10: '10.4'

# %%
int("10j")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-6efdd42f501b> in <module>()
# ----> 1 int("10j")
#
# ValueError: invalid literal for int() with base 10: '10j'

# %%
int("104")
type("104")
# Out:
# str

# %%
float("2.5")
# Out:
# 2.5

# %%
a = "11"
type(int(a))
# Out:
# int

# %%
int(a)
# Out:
# 11

# %%
type(a)  # hafızada bir yer tutmaz variable atamalısın değiştirmek için
# Out:
# str

# %%
a = 3
b = float(a)
print(b)
print(type(b))
# Out:
# 3.0
# <class 'float'>

# %%
x = 39
v = "11"
y = "2.5"
z = "I am at_"
print(x-int(v))
print(x-float(y))
print(z+str(x))
# Out:
# 28
# 36.5
# I am at_39

# %%
3 + "3"   # int ve str toplanamaz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-ad516fe62d24> in <module>()
# ----> 1 3 + "3"   # int ve str toplanamaz
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3 + int("3")
# Out:
# 6

# %%
"3" + "3"
# Out:
# '33'

# %%
str(3) + "3"
# Out:
# '33'

# %%
print("3" + "3")
# Out:
# 33

# %%
# float ile işleme girince sonuç kesinlikle float olur

# %%
a = 3 + 3.14
print(a)
print(type(a))
# Out:
# 6.140000000000001
# <class 'float'>

# %%
a = 123
b = 1.23
c = a + b
print("Type of a: ", type(a))
print("Type of b: ", type(b))
print("Value of c: ", c)
print("Type of c: ", type(c))
# Out:
# Type of a:  <class 'int'>
# Type of b:  <class 'float'>
# Value of c:  124.23
# Type of c:  <class 'float'>

# %%
a = 123
b = "456"
print("Type of a: ", type(a))
print("Type of b: ", type(b))
print(a + b)
# Out:
# Type of a:  <class 'int'>
# Type of b:  <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-a03765ce40c9> in <module>()
#       3 print("Type of a: ", type(a))
#       4 print("Type of b: ", type(b))
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 123
b = "456"
print("Type of a: ", type(a))
print("Type of b: ", type(b))
print(a + int(b))
print(str(a) + b)
# Out:
# Type of a:  <class 'int'>
# Type of b:  <class 'str'>
# 579
# 123456

# %%
a = 123
b = "456"
print("Type of a: ", type(a))
print("Type of b before Casting: ", type(b))
c = int(b)
print("Type of c after Casting: ", type(c))
d = a + c
print("Sum_of_aand_b: ", d)
print("Type of c: ", type(d))
# Out:
# Type of a:  <class 'int'>
# Type of b before Casting:  <class 'str'>
# Type of c after Casting:  <class 'int'>
# Sum_of_aand_b:  579
# Type of c:  <class 'int'>

# %%
a = 123
b = "456"
print("Type of a: ", type(a))
print("Type of b before Casting: ", type(b))
c = int(b)
print("Type of c after Casting: ", type(c))
d = a + c
print("Sum_of_aand_b: ", c)
print("Type of c: ", type(c))
# Out:
# Type of a:  <class 'int'>
# Type of b before Casting:  <class 'str'>
# Type of c after Casting:  <class 'int'>
# Sum_of_aand_b:  456
# Type of c:  <class 'int'>
