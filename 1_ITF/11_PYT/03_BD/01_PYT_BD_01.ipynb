# %%
# 01_PYT_BD_01

# %%
# -----------General_InjformationS--------------

# %%
# Easy to learn
# Easy to use
# Easy to run
# Easy to develop
# Easy to teach

# %%
# 2019-2020 yılı GitHub en çok kullanılan 2. yazılım dili Python
# Github, Stackoverflow
# Guido van Russom
# High Level Programming Language
# open source, web based, cell based>>>jupyter based

# %%
print("Hello World")
# Out:
# Hello World

# %%
# Function >>>>>  name() for example

# %%
# "", '', '''''', """"""", " " buradaki boşluk bile bir stringdir.

# %%
print('Hello World")
# Out:
#   File "<ipython-input-8-91c08de83dce>", line 1
#     print('Hello World")
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
print('engin')
# Out:
# engin

# %%
print('I'am engin')
# Out:
#   File "<ipython-input-10-1d92cc5d74fa>", line 1
#     print('I'am engin')
#               ^
# SyntaxError: invalid syntax

# %%
print("I'am engin")
# Out:
# I'am engin

# %%
print('I said "hello" to my friend')
# Out:
# I said "hello" to my friend

# %%
# 3 lü tırnak kullanımı her sorunun önüne geçer,
# Özellikle uzun metinlerde.

# %%
print('''engin 
ahmet''')   # bu şekilde 2 satırda yazdırma şansı veriyor.
# Out:
# engin
# ahmet

# %%
print(''engin
ahmet'')
# Out:
#   File "<ipython-input-21-f7f6db48ebb8>", line 1
#     print(''engin
#                 ^
# SyntaxError: invalid syntax

# %%
print('engin
ahmet')
# Out:
#   File "<ipython-input-22-52790283e7e5>", line 1
#     print('engin
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
print("3.14")
print(3.14)
# Out:
# 3.14
# 3.14

# %%
print("print(3.14)")
# Out:
# print(3.14)

# %%
print(''''engin"''')
# Out:
# 'engin"

# %%
print('''''''''''''''''''''')
# Out:
#   File "<ipython-input-35-b101551fb9db>", line 1
#     print('''''''''''''''''''''')
#                                  ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
print('engin")
# Out:
#   File "<ipython-input-36-f223edb243ec>", line 1
#     print('engin")
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
print()      #  2 tane boş satır veriri
print("")

# %%
print()
print("")
print('''')
# Out:
#   File "<ipython-input-40-3df1326cd99c>", line 3
#     print('''')
#                ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
# PEP 8 Rules the next lesson
