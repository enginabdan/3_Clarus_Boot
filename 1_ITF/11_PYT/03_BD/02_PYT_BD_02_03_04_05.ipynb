# %%
# 01_PYT_BD_02_03_04_05

# %%
# -----------First_Step_Coding-----------------------
# -----------PEP8-----------------------
# -----------Comments_Docstrings-----------------------
# -----------Naming_Variables-----------------------

# %%
# In Line Comment
# Single Line Comment
# Multi Line Comment

# %%
# Comments must be 
# Sufficient yeterli düzeyde açıklamalı
# Necessary gerekli olmalı
# Updated update edilebilmeli

# %%
print("engin")  # Bu bir Inline Commenttir.
# Out:
# engin

# %%
print("engin")
# Bu bir Singleline Comment
# Out:
# engin

# %%
print("engin")
# print("engin")
# print("merhaba")
# Out:
# engin

# %%
# Docstrings
# def function_name()
# print(function_name.__doc__) # __doc__ 2şer tane alt çizgi var
print(print.__doc__)
# Out:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.

# %%
print(map.__doc__)
# map() : print(map.__doc__)
# sum() : print(sum.__doc__)
# input() : print(input.__doc__)
# Out:
# map(func, *iterables) --> map object
#
# Make an iterator that computes the function using arguments from
# each of the iterables.  Stops when the shortest iterable is exhausted.

# %%
print(sum.__doc__)
# Out:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.

# %%
print(input.__doc__)
# Out:
# Forward raw_input to frontends
#
#         Raises
#         ------
#         StdinNotImplentedError if active frontend doesn't support stdin.

# %%
# ------------Naming Variables-----------------

# %%
# PEP 8 Rules  
# PEP: Python Enhancement Proposol
# Variable naming; be carefull not to name function name
#   variable name = value planet = "jupyter"

# %%
x = 11    # assigning
print(x)
# Out:
# 11

# %%
x = "engin"
y = 3.14
z = 3
print(x)
print(y)
print(z)
# Out:
# engin
# 3.14
# 3

# %%
my_age = 33
your_age = 30
my_age = your_age
print(my_age)
# Out:
# 30

# %%
x = 10
x = 11
x = 12
x = 13
print(x)
# Out:
# 13

# %%
x = 10
print(x)
x = 11
print(x)
x = 12
print(x)
x = 13
print(x)
# Out:
# 10
# 11
# 12
# 13

# %%
xx = 11
yy = 21
zz = 15

# %%
xx = yy
zz = xx

# %%
print(xx)
print(yy)
print(zz)
# Out:
# 21
# 21
# 15

# %%
Number-one = 3 # -one özel bir karakter olduğundan hata verir
# Out:
#   File "<ipython-input-32-aa0d171dc5f8>", line 1
#     Number-one = 3
#                   ^
# SyntaxError: can't assign to operator

# %%
VAR = "ENGİN"  # çalışır ancak büyük harf kullanmamalıyız.
l = 3  # tek başına küçük le kullanma
I = 3 # büyük i kullanma
O = 0  # Büyük o kullanma
1 = "engin"  # variable sayı verme.

# %%
time_0 = 11  # 0 kullanma variableda sıfır ile büyük o karışır.
time_O = 12

# %%
import = 5  # reserve function
# Out:
#   File "<ipython-input-45-3c1c1f1c3721>", line 1
#     import = 5
#            ^
# SyntaxError: invalid syntax

# %%
if    # Bunlar reserve edilmiş fonksiyonlar
in
with
False
# Out:
#   File "<ipython-input-46-aaa766678909>", line 1
#     if    # Bunlar reserve edilmiş fonksiyonlar
#                                                ^
# SyntaxError: invalid syntax

# %%
# Büyük küçük harf duyarlı python case sensitive

# %%
x = 0
X = 1
print(x)  # Case sensitive olduğundan küçük x : 0 aldı
# Out:
# 0

# %%
# False
# True
# None    bunlar baş harfi büyük

# %%
# 2me         # başta 2 olmaz
# Big Boss    # arada boşluk olmaz
# big-boss    # arada tire olmaz
# big_boss    # bu olur
# data4me     # bu olur
# first!      # noktalama işareti kullanılmaz
# xy#@!v      # özel ve noktalama işareti olmaz
# $price      # özel işaret olmaz

# %%
# students = .... # olur
# s = ....        # kötü örnek
# st = .....      # kötü örnek

# %%
# Big Data  >>>>  big_data
# Averaga Income of February >>>>  avg_income_feb = ....

# %%
# amount of rotten fruits             >>>  amnt_rottn_frts
# the list of prime numbers           >>>  lst_prm_num
# the list of mathematics exam scores >>>  math_exm_scrs_lst
