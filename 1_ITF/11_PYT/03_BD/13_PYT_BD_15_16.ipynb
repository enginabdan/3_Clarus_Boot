# %%
# 02_PYT_BD_15_16

# %%
# -----------Sets--------------
# ----Control Flow Statements-----
    # -----------Conditionals--------------
    # -----------Loops--------------

# %%
# Main Operations with Sets
#     .add()
#     .remove()
#     .intersection() "&"
#     .union() "|"
#     .difference() "-"

# %%
a = set()
a.add("a")
print(a)
# Out:
# {'a'}

# %%
a = set("philadelphia")
b = set("dolphin")
print(a)
print(b)
# Out:
# {'h', 'p', 'i', 'e', 'd', 'l', 'a'}
# {'h', 'p', 'o', 'i', 'd', 'l', 'n'}

# %%
print(a-b)
print(a.difference(b))
print(type(a-b))
print(type(a.difference(b)))
# Out:
# {'e', 'a'}
# {'e', 'a'}
# <class 'set'>
# <class 'set'>

# %%
print(a|b)
print(a.union(b))
print(type(a|b))
print(type(a.union(b)))
# Out:
# {'h', 'p', 'o', 'e', 'i', 'd', 'l', 'n', 'a'}
# {'h', 'p', 'o', 'e', 'i', 'd', 'l', 'n', 'a'}
# <class 'set'>
# <class 'set'>

# %%
 a = set("16/05/2021")
 print(a)
# Out:
# {'5', '1', '0', '/', '2', '6'}

# %%
a = {"16/05/2021"}
print(a)
# Out:
# {'16/05/2021'}

# %%
a = {"16/05/2021"}
b = set("16/05/2021")
c = list(a)
d = list(b)
print(a)
print(b)
print(c)
print(d)
# Out:
# {'16/05/2021'}
# {'5', '1', '0', '/', '2', '6'}
# ['16/05/2021']
# ['5', '1', '0', '/', '2', '6']

# %%
a = [1,2,3,3,3,3,4,4,5,5]
print(list(set(a)))
print(list(tuple(a)))
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 3, 3, 3, 4, 4, 5, 5]

# %%
a = set("washington")
b = set("wellington")
print(a|b)
print(b.union(a))
print(a&b)
print(b.intersection(a))
print(a-b)
print(b.difference(a))
# Out:
# {'h', 'o', 'i', 'w', 'e', 's', 't', 'n', 'l', 'a', 'g'}
# {'h', 'o', 'i', 'e', 'w', 's', 't', 'n', 'l', 'a', 'g'}
# {'o', 'i', 'w', 't', 'n', 'g'}
# {'o', 'i', 'w', 't', 'n', 'g'}
# {'s', 'h', 'a'}
# {'l', 'e'}

# %%
# -----------Control Flow Statements--------
    # -----------Conditionals--------------
    # -----------Loops--------------

# %%
# -----------Conditionals--------------
    # -----------if statement--------------
    # -----------Comparison Operators------
    # -----------if-else statement---------
    # -----------if-elif-else statement----
    # -----------Nested if-elif-else statement

# %%
if a > b:
    print("a is greater tahn b")

# %%
# if condition:
#     body1  if'in ilk bodysi
#     body2  if'in ikinci bodysi
# body3      if ile ilgisiz her halukarda

# %%
# case sensitive
# indentation sensitive

# %%
if True:  # True iken çalışır
    print("it is true")
# Out:
# it is true

# %%
if False: # False iken çalışmaz
    print("it is true")

# %%
if 1:  # Truthy iken çalışır
    print("it is true")
# Out:
# it is true

# %%
if 0: # Falsy iken çalışmaz (None,{},[],... )
    print("it is true")

# %%
price = 2200
if price<= 2200 :
    print("yes")
else:
    print("No")
# Out:
# yes

# %%
price = "2200"
if price<= "2200" :
    print("yes")
else:
    print("No")
# Out:
# yes

# %%
"a" == "a"
# Out:
# False

# %%
"a" < "a"
# Out:
# False

# %%
"a" > "a"
# Out:
# False

# %%
minced = True
bread = True
# greens
lettuce = True
pepper = False

store = True

hamburger = minced and bread and store and (lettuce or pepper)

if hamburger :
    print("Bon Apetite")
# Out:
# Bon Apetite

# %%
# equal                   : ==
# not equal               : !=
# greater than            : >
# greater than or equal   : >=
# less than               : <
# less than or equal      : <=
# Return to True or False
# print, max, bool, any, all bunlar True False run

# %%
a = 14
if a > 3:
    print("There is still")
# Out:
# There is still

# %%
print(1 == 1)
print("engin" == "Engin")
print(12 < 12.1)
print("hard" != "easy")
# Out:
# True
# False
# True
# True

# %%
a = set("TWELVE PLUS ONE")
b = set("ELEVEN PLUS TWO")
print(a)
print(b)
if a == b:
    print("We are the same!")
# Out:
# {'T', 'N', 'L', 'P', ' ', 'S', 'U', 'W', 'E', 'O', 'V'}
# {'T', 'N', 'L', 'P', ' ', 'S', 'U', 'W', 'E', 'O', 'V'}
# We are the same!

# %%
a = input("Write yes or no :").title().strip()
if a == "Yes" :
    print("You entered True")
# Out:
# You entered True

# %%
a = input("Write yes or no :").title().strip() == "Yes"
print("You entered :", a)
# Out:
# You entered : True

# %%
print("You entered :", input("Write yes or no :").title().strip() == "Yes")
# Out:
# You entered : False

# %%
a = input("Write your name :").title().strip()
if a == "Engin":
    print("You are on the right way.")
else:
    print("You are on the wrong way.")
# Out:
# You are on the right way.

# %%
a = int(input("Enter a number :").strip())
b = a % 2
if b == 0 :
    print(a, "is even")
else:
    print(a, "is odd")
# Out:
# 14 is even

# %%
a = int(input("Enter a number :").strip())
b = a % 2
if b == 0 :
    print("{} is even".format(a))
else:
    print("{} is even".format(a))
# Out:
# 12 is even

# %%
a = int(input("Enter a number :").strip())
b = a % 2
if b == 0 :
    print(f"{a} is even")
else:
    print(f"{a} is even")
# Out:
# 11 is even

# %%
a = float(input("Enter negative or positive number :"))
if a > 0 :
    print("Positive number")
else:
    print("Negative number")
# Out:
# Negative number

# %%
a = float(input("Enter first number :"))
b = float(input("Enter second number :"))
if a > b :
    print("The large number is", a)
else:
    print("The large number is", b)
# Out:
# The large number is 12.0

# %%
a = float(input("Enter first number :"))
b = float(input("Enter second number :"))
if a > b :
    larger = a
else:
    larger = b
print("The larger number is :", larger)
# Out:
# The larger number is : 2.0

# %%
a = int(input("Enter a number :"))
if a == 2 :
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
a = True
if a :
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
# --------------if elif else---------------

# %%
# if con1 :
#     body1
# elif con2 :
#     body2
# elif con3 :
#     body3
#     .
#     .
#     .
# else:
#     bodyn

# %%
a = "engin"
if a == "azra" :
    print("1")
elif a == "neda" :
    print("2")
elif a == "aden" :
    print("3")
else:
    print("4")
# Out:
# 4
