# %%
# 01_PYT_BD_08

# %%
# -----------Boolean--------------
# -----------The Strength of String--------------

# %%
# True as value
# False as value
# Truth values

# %%
# not This list is the priority
# and Looking False gets 1st False or last True if all True
# or  Looking True gets 1st True or last False if all False

# %%
bool_var = False and not True
print(bool_var)
# Out:
# False

# %%
True and False or not False or False
# Out:
# True

# %%
# None
# 0, 0.0, 0j
# "", [], {}, ()
# Others are True

# %%
print(2 and 3)  # Truthy
# Out:
# 3

# %%
print(1 and 0)  # Falsy
# Out:
# 0

# %%
3 and 2 and 1
# Out:
# 1

# %%
bool(1)
# Out:
# True

# %%
bool("0")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
print(2 and "engin")
print([] and "azra")
print(None and ())
# Out:
# engin
# []
# None

# %%
2 or 3
# Out:
# 2

# %%
None or 1
# Out:
# 1

# %%
none = "none"
none or 1
# Out:
# 'none'

# %%
none = "False"
none or 1
# Out:
# 'False'

# %%
print(2 or "engin")
# Out:
# 2

# %%
print(2 or "engin")
print([] or "azra")
print(None or ())
print({} or 0)
print({0} or False)
# Out:
# 2
# azra
# ()
# 0
# {0}

# %%
True or False and "False" and not "False" and 0
# not neyin yanına gelirse gelsin True veya False yapar
# Out:
# True

# %%
not ("None" or None) and False or ("and" and not ())
# Out:
# True

# %%
# Kadayif
# Kernels (Walnut, Hazelnut, Peanut)
# Sherbet (Water and Sugar)
# Egg

# %%
# kadayif = None

# # iç malzeme
# fındık = None
# fıstık = None
# ceviz = None

# # Şerbet
# su = None
# şeker = None

# yumurta = None

# yedim = kadayif and (su and şeker) and \
# (fındık or fıstık or ceviz) and yumurta

# %%
kadayif = True

# iç malzeme
findik = True
fistik = False
ceviz = False

# Şerbet
su = True
seker = False

yumurta = True

yedim = kadayif and (su and seker) and \
(findik or fistik or ceviz) and yumurta

yedim
# Out:
# False

# %%
kadayif = True

# iç malzeme
findik = True
fistik = False
ceviz = False

# Şerbet
su = True
seker = True

yumurta = True

# icecek
cay = False
limonata = True
mesrubat = False

yedim = kadayif and (su and seker) and \
(findik or fistik or ceviz) and yumurta and \
(cay or limonata or mesrubat)

yedim
# Out:
# True

# %%
print(None or 1)
# Out:
# 1

# %%
False or True or False
# Out:
# True

# %%
not False and True
# Out:
# True

# %%
a = " "
b = "False"
c = True
d = ""
print(a or b or c and not d)

# %%
print("None or True and 1")
# Out:
# None or True and 1

# %%
None or True and 1
# Out:
# 1

# %%
A = True
B = False
logic = (A or B) and (not A)
print(logic)
# Out:
# False

# %%
# -----------The Strength of String--------------

# %%
# Indexing and Slicing
# Formating with Arithmetic
# Formating with % operator
# Formating with string.format()
# Formating with "f-string"

# %%
"engin abdan"
# Out:
# 'engin abdan'

# %%
"engin"[2]
# Out:
# 'g'

# %%
a = "engin"
a[2]
# Out:
# 'g'

# %%
a = "eng-in ."
a[6]
# Out:
# ' '

# %%
"engin 34"
# Out:
# 'engin 34'

# %%
var = "engin 34"
print(var[6])
print(type(var))
# Out:
# 3
# <class 'str'>

# %%
fruit = 'Orange'

print('Word                   : ' , fruit)
print('First letter           : ' , fruit[0])
print('Second letter          : ' , fruit[1])
print("3rd to 5th letters     : " , fruit[2:5])
print("Letter all after 3rd   : " , fruit[2:])
# Out:
# Word                   :  Orange
# First letter           :  O
# Second letter          :  r
# 3rd to 5th letters     :  ang
# Letter all after 3rd   :  ange

# %%
"engin_azra--neda?-!aden"[2:5:2]
# Out:
# 'gn'

# %%
a = "engin_azra--neda?-!aden"
a[-2:-4:-2]
# Out:
# 'e'

# %%
a = "engin_azra--neda?-!aden"
a[-1:2:-1]
# Out:
# 'neda!-?aden--arza_ni'

# %%
a = "engin_azra--neda?-!aden"
a[10:-14:-2]
# Out:
# '-'

# %%
a = "engin_azra--neda?-!aden"
a[::-3]
# Out:
# 'na?e-znn'

# %%
a = "engin_azra--neda?-!aden"
a[::3]
# Out:
# 'eiaana!e'

# %%
a = input("Bir sayı giriniz: ")
print(a)
print(type(a))
print(type(int(a)))
# Out:
# Bir sayı giriniz: 67
# 67
# <class 'str'>
# <class 'int'>

# %%
a = input("First Number: ")
b = input("Second Number: ")
print("Total: ", a+b)
# Out:
# First Number: 10
# Second Number: 5
# Total:  105

# %%
a = input("First Number: ")
b = input("Second Number: ")
print("Total: ", int(a) + int(b))
# Out:
# First Number: 10
# Second Number: 5
# Total:  15

# %%
a = int(input("First Number: "))
b = int(input("Second Number: "))
print("Total: ", a+b)
# Out:
# First Number: 10
# Second Number: 2
# Total:  12
