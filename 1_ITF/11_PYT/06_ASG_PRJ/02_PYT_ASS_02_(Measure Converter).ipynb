# %%
# 02_PYT_ASS_02_(Measure Converter)

# %% [markdown]
# Task-1:
#
#     1. Write a short Python program that asks the user to enter Celsius temperature (it can be a decimal number),
#
#     2. Converts the entered temperature into Fahrenheit degree and prints the result.
#
# Task-2:
#
#     1. Write a short Python program that asks the user to enter a distance (it can be a decimal number) in kilometers,
#
#     2. Converts the entered distance into miles and prints the result.

# %%
Temp_Cel = input("Please enter the temperature in Celcius :")
Temp_Cel = float(Temp_Cel)  # Celsius, Fahrenheit Formülü °F = °C × 1.8 + 32
Temp_Fah = Temp_Cel*1.8+32
Temp_Fah = float(Temp_Fah)
print(Temp_Fah)
print( )
print( )
Dist_Km = input("Please enter the distance in kilometer :")
Dist_Km = float(Dist_Km)  # Mil, Km Formülü Mil = Km x 0.62137
Dist_Mil = Dist_Km*0.62137
Dist_Mil = float(Dist_Mil)
print(Dist_Mil)
# Out:
# 68.0
#
#
# 13.04877

# %%
Temp_Cel = float(input("Please enter the temperature in Celcius :"))
Temp_Fah = float(input("Please enter the temperature in Fahrenheit :"))
Dist_Km = float(input("Please enter the distance in kilometer :"))
Dist_Mil = float(input("Please enter the distance in Mile :"))
# Dist_Km = input("Please enter the distance in kilometer :")
print("%d Celsius is %d Fahrenheit" %(Temp_Cel, Temp_Cel*1.8+32))
print("%d Fahrenheit is %d Celsius" %(Temp_Fah, (Temp_Fah-32)/1.8))
print("%d Kilometer is %d Mile" %(Dist_Km, Dist_Km*0.62137))
print("%d Mile is %d Kilometer" %(Dist_Mil, Dist_Mil/0.62137))
# Out:
# 20 Celsius is 68 Fahrenheit
# 90 Fahrenheit is 32 Celsius
# 1000 Kilometer is 621 Mile
# 2000 Mile is 3218 Kilometer
