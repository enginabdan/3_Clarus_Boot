# %%
# 01_PYT_ASS_01_(Profit Calculator)

# %% [markdown]
# Problem :
#
#     1. If you had deposited a coin on the cryptocurrency exchange that brought 7% fixed profit daily for a week.
#
#     2. How much would your $ 1000 reach at the end of the 7th day?

# %%
Anapara=1000

Günlük_Faiz=0.07

Dönem_Sayısı=7

Toplam_Para=Anapara*(1+Günlük_Faiz)**Dönem_Sayısı

print(Toplam_Para)
# Out:
# 1605.7814764784307

# %%
a=1000
faiz=0.07
dönem=7
for i in range(7):
    a=a+a*faiz
    i+=1
print(a)
# Out:
# 1605.78147647843
