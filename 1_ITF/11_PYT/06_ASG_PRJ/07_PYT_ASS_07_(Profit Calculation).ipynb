# %%
# 07_PYT_ASS_07_(Profit Calculation)

# %% [markdown]
# Task - 1 :
#
#     1. You work for a manufacturer as a programmer and have been asked to calculate the total profit made on the sales of a product.
#
#     2. You are given a dictionary (sales) containing the cost price per unit (in dollars), sell price per unit (in dollars), and the beginning inventory.
#
#     3. Write a program to return the total profit made, rounded to the nearest dollar.
#
#     4. Assume all of the inventory has been sold.
#
#     5. The name and the keys of the dictionary are constant, so use them as they are.
#
# Task - 2 :
#
#     1. Your boss wants you to prepare the payrolls of the workers in your department.
#
#     2. You have to convert the amount of dollars into payroll format.
#
#     3. In order to help move things along, you have volunteered to write a code that will take a float and return the money in the following format (as dollars and cents).

# %%
sales = {"cost_value": 31.87, "sell_value": 45.00, "inventory": 1000}  
print(round((sales["sell_value"]-sales["cost_value"])*sales["inventory"]), "\n")
print()
a = float(input("Give the payroll"))
b = "$%.2f" %(a)
print(b)
# Out:
# 13130
#
#
# $4.00
