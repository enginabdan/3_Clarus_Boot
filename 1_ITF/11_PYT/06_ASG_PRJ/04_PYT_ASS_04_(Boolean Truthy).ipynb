# %%
# 04_PYT_ASS_04_(Boolean Truthy)

# %% [markdown]
# Task :
#
#     1. Using the all following items once each,
#
#     2. Set a correct boolean expression that returns write me.
#
#     3. Use the print() function to display the result.
#
#         a. 0
#         b. and
#         c. not
#         d. "write me"

# %%
print(not 0 and "write me")
# Out:
# write me
