# %%
# -----------08_DAwPYTH_BP_08_(Pandas)--------------
# ---------------Dropping,Selecting-----------------

# %%
# SUMMARY

# Select column,
# Multi column selecting,
# Create new columns
# drop() function,
# shape
# set_index,
# loc and iloc.

df = pd.DataFrame(np.arange(12).reshape(3, 4), columns=['A', 'B', 'C', 'D'])
df.drop(['B', 'C'], axis=1)
df.describe().transpose()

df["Age"]
type(df["Age"])

df[["Age", "Fare"]]
df["Age"] + df["Fare"]  
df["Age"] / df["Fare"]  
100 * df["Age"] / df["Fare"]  
df["Percentage"] = 100 * df["Age"] / df["Fare"] 
df["Division"] = df["Age"] / df["Fare"] 
df["Percentage"] = np.round(100 * df["Age"] / df["Fare"], 2)
df["Division"] = np.round(df["Age"] / df["Fare"], 2)

df.drop("Percentage", axis=1) # temporary
df.drop("Division", axis=1, inplace=True) # permanent
df.drop(1, axis=0)

df.shape
df.shape[0]

df.index
df.set_index("Division")
df.reset_index() # temporary
df = df.reset_index() # permanent

df.iloc[0] # for the 1st row
df.loc["female"] # one str variable
df.iloc[0:4] # more than 1 row

df.drop("female", axis=0) # temporary
df.drop("female", axis=1, inplace=True) # permanent

df.append(a) # temporary
df = df.append(a) # permanent

# %%
# drop(): Remove rows / columns:
    # by specifying label names and corresponding axis,
    # by specifying directly index or column names.
# When using a multi-index, labels on different levels can be removed by specifying the level.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe().transpose()
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 1 sütunu çekip gösterme
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
# a = ["Age", "Fare"]  bu şekilde de olur, alttaki gibi de olur
df[["Age", "Fare"]]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
# 2 sütunu birbiri ile toplama
df["Age"] + df["Fare"]
# Out:
# 0       29.2500
# 1      109.2833
# 2       33.9250
# 3       88.1000
# 4       43.0500
#          ...
# 886     40.0000
# 887     49.0000
# 888         NaN
# 889     56.0000
# 890     39.7500
# Length: 891, dtype: float64

# %%
# 2 sütunu birbiri ile bölme
df["Age"] / df["Fare"]
# Out:
# 0      3.034483
# 1      0.533084
# 2      3.280757
# 3      0.659134
# 4      4.347826
#          ...
# 886    2.076923
# 887    0.633333
# 888         NaN
# 889    0.866667
# 890    4.129032
# Length: 891, dtype: float64

# %%
# 2 sütunu birbiri ile bölüp % şeklinde gösterme
100 * df["Age"] / df["Fare"]
# Out:
# 0      303.448276
# 1       53.308419
# 2      328.075710
# 3       65.913371
# 4      434.782609
#           ...
# 886    207.692308
# 887     63.333333
# 888           NaN
# 889     86.666667
# 890    412.903226
# Length: 891, dtype: float64

# %%
# yeni bir sütunda yukarıdaki orantıyı gösterme
df["Percentage"] = 100 * df["Age"] / df["Fare"]

# %%
# en sona eklendi
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Percentage
# 0      0         A/5 21171   7.2500   NaN        S  303.448276
# 1      0          PC 17599  71.2833   C85        C   53.308419
# 2      0  STON/O2. 3101282   7.9250   NaN        S  328.075710
# ...

# %%
# yeni bir sütunda Oranı gösterme
df["Division"] = df["Age"] / df["Fare"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Percentage  Division
# 0      0         A/5 21171   7.2500   NaN        S  303.448276  3.034483
# 1      0          PC 17599  71.2833   C85        C   53.308419  0.533084
# 2      0  STON/O2. 3101282   7.9250   NaN        S  328.075710  3.280757
# ...

# %%
# Halihazırda varolan bir sütuna yeni bir atama yaparsanız o sütun ismi kalır altına yeni veriler gelir.

# %%
df["Percentage"] = np.round(100 * df["Age"] / df["Fare"], 2)

# %%
df["Division"] = np.round(df["Age"] / df["Fare"], 2)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Percentage  Division
# 0      0         A/5 21171   7.2500   NaN        S      303.45      3.03
# 1      0          PC 17599  71.2833   C85        C       53.31      0.53
# 2      0  STON/O2. 3101282   7.9250   NaN        S      328.08      3.28
# ...

# %%
# axis=0 satır, axis=1 sütun işlem yapar, satır veya sütun silmek için drop
df.drop("Percentage", axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Gerçekte silmedi yukarıda geçici sildi "Percentage" sütununu
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Kalıcı olarak silmek için inplace de kullanabilirsin bunu da.
df = df.drop("Percentage", axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# inplace True olarak da silebilirsin
df.drop("Division", axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1. satırı silme geçici olarak
df.drop(1, axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.shape[0]
# Out:
# 891

# %%
df.shape[1]
# Out:
# 12

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df["Percentage"] = np.round(100 * df["Age"] / df["Fare"], 2)

# %%
df["Division"] = np.round(df["Age"] / df["Fare"], 2)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Aşağıda da görüleceği üzere Division artık bir colum değil name of index ve 2. satırda, 1. satırda colum nameler var.
# Geçici olarak yapar.
df.set_index("Division")
# Out:
#           PassengerId  Survived  Pclass  \
# Division
# 3.03                1         0       3
# 0.53                2         1       1
# 3.28                3         1       3
# 0.66                4         1       1
# 4.35                5         0       3
# ...               ...       ...     ...
# 2.08              887         0       2
# 0.63              888         1       1
# NaN               889         0       3
# 0.87              890         1       1
# 4.13              891         0       3
#
#                                                        Name     Sex   Age  \
# Division
# 3.03                                Braund, Mr. Owen Harris    male  22.0
# 0.53      Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3.28                                 Heikkinen, Miss. Laina  female  26.0
# 0.66           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4.35                               Allen, Mr. William Henry    male  35.0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Kalıcı olarak yapmak istersen
df = df.set_index("Division")

# %%
df
# Out:
#           PassengerId  Survived  Pclass  \
# Division
# 3.03                1         0       3
# 0.53                2         1       1
# 3.28                3         1       3
# 0.66                4         1       1
# 4.35                5         0       3
# ...               ...       ...     ...
# 2.08              887         0       2
# 0.63              888         1       1
# NaN               889         0       3
# 0.87              890         1       1
# 4.13              891         0       3
#
#                                                        Name     Sex   Age  \
# Division
# 3.03                                Braund, Mr. Owen Harris    male  22.0
# 0.53      Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3.28                                 Heikkinen, Miss. Laina  female  26.0
# 0.66           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4.35                               Allen, Mr. William Henry    male  35.0
# ...

# %%
# Yaptığın kalıcıyı geçici geri almak için ise:
df.reset_index()
# Out:
#      Division  PassengerId  Survived  Pclass  \
# 0        3.03            1         0       3
# 1        0.53            2         1       1
# 2        3.28            3         1       3
# 3        0.66            4         1       1
# 4        4.35            5         0       3
# ..        ...          ...       ...     ...
# 886      2.08          887         0       2
# 887      0.63          888         1       1
# 888       NaN          889         0       3
# 889      0.87          890         1       1
# 890      4.13          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df
# Out:
#           PassengerId  Survived  Pclass  \
# Division
# 3.03                1         0       3
# 0.53                2         1       1
# 3.28                3         1       3
# 0.66                4         1       1
# 4.35                5         0       3
# ...               ...       ...     ...
# 2.08              887         0       2
# 0.63              888         1       1
# NaN               889         0       3
# 0.87              890         1       1
# 4.13              891         0       3
#
#                                                        Name     Sex   Age  \
# Division
# 3.03                                Braund, Mr. Owen Harris    male  22.0
# 0.53      Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3.28                                 Heikkinen, Miss. Laina  female  26.0
# 0.66           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4.35                               Allen, Mr. William Henry    male  35.0
# ...

# %%
# Yaptığın kalıcıyı kalıcı geri almak için ise:
df = df.reset_index()

# %%
df
# Out:
#      level_0  index  Division  PassengerId  Survived  Pclass  \
# 0          0      0      3.03            1         0       3
# 1          1      1      0.53            2         1       1
# 2          2      2      3.28            3         1       3
# 3          3      3      0.66            4         1       1
# 4          4      4      4.35            5         0       3
# ..       ...    ...       ...          ...       ...     ...
# 886      886    886      2.08          887         0       2
# 887      887    887      0.63          888         1       1
# 888      888    888       NaN          889         0       3
# 889      889    889      0.87          890         1       1
# 890      890    890      4.13          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df = df.set_index("Division")

# %%
df.head()
# Out:
#           level_0  index  PassengerId  Survived  Pclass  \
# Division
# 3.03            0      0            1         0       3
# 0.53            1      1            2         1       1
# 3.28            2      2            3         1       3
# 0.66            3      3            4         1       1
# 4.35            4      4            5         0       3
#
#                                                        Name     Sex   Age  \
# Division
# 3.03                                Braund, Mr. Owen Harris    male  22.0
# 0.53      Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3.28                                 Heikkinen, Miss. Laina  female  26.0
# 0.66           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4.35                               Allen, Mr. William Henry    male  35.0
#
#           SibSp  Parch            Ticket     Fare Cabin Embarked  Percentage
# Division
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#      Division  level_0  index  PassengerId  Survived  Pclass  \
# 0        3.03        0      0            1         0       3
# 1        0.53        1      1            2         1       1
# 2        3.28        2      2            3         1       3
# 3        0.66        3      3            4         1       1
# 4        4.35        4      4            5         0       3
# ..        ...      ...    ...          ...       ...     ...
# 886      2.08      886    886          887         0       2
# 887      0.63      887    887          888         1       1
# 888       NaN      888    888          889         0       3
# 889      0.87      889    889          890         1       1
# 890      4.13      890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df = df.set_index("Sex")

# %%
df
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
# ...          ...      ...    ...          ...       ...     ...
# male        2.08      886    886          887         0       2
# female      0.63      887    887          888         1       1
# female       NaN      888    888          889         0       3
# male        0.87      889    889          890         1       1
# male        4.13      890    890          891         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# ...

# %%
# Tek satırı almak için
df.iloc[0]
# Out:
# Division                          3.03
# level_0                              0
# index                                0
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Percentage                      303.45
# Name: male, dtype: object

# %%
# string olan bir veya birden fazla satırı almak için
# bir variable almak için, df.loc["female"],
# birden fazla variable almak için df.loc[["male", "female"]] 
df.loc["female"]
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# female      2.43        8      8            9         1       3
# female      0.47        9      9           10         1       2
# ...          ...      ...    ...          ...       ...     ...
# female      0.96      880    880          881         1       2
# female      2.09      882    882          883         0       3
# female      1.34      885    885          886         0       3
# female      0.63      887    887          888         1       1
# female       NaN      888    888          889         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# ...

# %%
# Birden fazla satırı almak için
df.iloc[0:4]
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# female                             Heikkinen, Miss. Laina  26.0      0      0
# female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
#
#                   Ticket     Fare Cabin Embarked  Percentage
# Sex
# male           A/5 21171   7.2500   NaN        S      303.45
# female          PC 17599  71.2833   C85        C       53.31
# ...

# %%
df
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
# ...          ...      ...    ...          ...       ...     ...
# male        2.08      886    886          887         0       2
# female      0.63      887    887          888         1       1
# female       NaN      888    888          889         0       3
# male        0.87      889    889          890         1       1
# male        4.13      890    890          891         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# ...

# %%
# burada bir uniq satırı veya birden fazla satırı bu şekilde silebiliriz, geçici olarak
# Kalıcı olarak silmek istersek df = df.drop("female", axis=0) şeklinde yazmalıyız.
df.drop("female", axis=0)
# Out:
#       Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male      3.03        0      0            1         0       3
# male      4.35        4      4            5         0       3
# male       NaN        5      5            6         0       3
# male      1.04        6      6            7         0       1
# male      0.09        7      7            8         0       3
# ...        ...      ...    ...          ...       ...     ...
# male      2.67      883    883          884         0       2
# male      3.55      884    884          885         0       3
# male      2.08      886    886          887         0       2
# male      0.87      889    889          890         1       1
# male      4.13      890    890          891         0       3
#
#                                 Name   Age  SibSp  Parch            Ticket  \
# Sex
# male         Braund, Mr. Owen Harris  22.0      1      0         A/5 21171
# ...

# %%
df.head()
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# female                             Heikkinen, Miss. Laina  26.0      0      0
# female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# male                             Allen, Mr. William Henry  35.0      0      0
#
#                   Ticket     Fare Cabin Embarked  Percentage
# Sex
# ...

# %%
# en başta set ettiğimiz colum altındaki veriler string ve siz belli bir satırı silmek istiyorsunuz ve indexleme yapmak istiyorsunuz bu durumda df.iloc[] kullanmalısınız.

# %%
# bu şekilde geçici olarak yapılır.
df.iloc[2:5]
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# Sex
# female                        Heikkinen, Miss. Laina  26.0      0      0
# female  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# male                        Allen, Mr. William Henry  35.0      0      0
#
#                   Ticket    Fare Cabin Embarked  Percentage
# Sex
# female  STON/O2. 3101282   7.925   NaN        S      328.08
# female            113803  53.100  C123        S       65.91
# male              373450   8.050   NaN        S      434.78

# %%
df.head()
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# female                             Heikkinen, Miss. Laina  26.0      0      0
# female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# male                             Allen, Mr. William Henry  35.0      0      0
#
#                   Ticket     Fare Cabin Embarked  Percentage
# Sex
# ...

# %%
a = df.iloc[0]
a
# Out:
# Division                          3.03
# level_0                              0
# index                                0
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Percentage                      303.45
# Name: male, dtype: object

# %%
# ilk satırı en sona tekrar ekledik, geçici olarak
# kalıcı olarak yapmak istersen df = df.append(a) yapmalısın
df.append(a)
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
# ...          ...      ...    ...          ...       ...     ...
# female      0.63      887    887          888         1       1
# female       NaN      888    888          889         0       3
# male        0.87      889    889          890         1       1
# male        4.13      890    890          891         0       3
# male        3.03        0      0            1         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# ...

# %%
df
# Out:
#         Division  level_0  index  PassengerId  Survived  Pclass  \
# Sex
# male        3.03        0      0            1         0       3
# female      0.53        1      1            2         1       1
# female      3.28        2      2            3         1       3
# female      0.66        3      3            4         1       1
# male        4.35        4      4            5         0       3
# ...          ...      ...    ...          ...       ...     ...
# male        2.08      886    886          887         0       2
# female      0.63      887    887          888         1       1
# female       NaN      888    888          889         0       3
# male        0.87      889    889          890         1       1
# male        4.13      890    890          891         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# ...
