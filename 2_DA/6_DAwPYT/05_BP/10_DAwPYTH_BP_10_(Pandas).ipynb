# %%
# -----------10_DAwPYTH_BP_10_(Pandas)--------------
# ------Describing / Sorting / Missing Data --------

# %%
# SUMMARY

# apply() method
# apply() with lambda
# unique values
    # unique(),
    # nunique(),
    # value_counts() commands
# describe() >>> percentile, mean, std, ...
# sort_values()
# Statistical information
    # min(),
    # max(),
    # idmax(),
    # map(),
    # replace(),
    # duplicated(),
    # between(),
    # sample(),
    # nlargest()

str(123456789)[-4:]

def last_four(num):
    return str(num)[-4:]

df["CC Number"].apply(last_four)
df["last_four"] = df["CC Number"].apply(last_four)

df["CC Number"].mean()

def yelp(price):
    if price < 10:
        return "$"
    elif price >= 10 and price < 30:
        return "$$"
    else:
        return "$$$"

df["yelp"] = df["tip"].apply(yelp)
df[df["yelp"] == "$"].value_counts().sum()

df["tip"].apply(simple)
lambda num: num*2
df["tip"].apply(lambda num: num*2)
df[["total_bill", "tip"]].apply(lambda df: percentage(df["total_bill"], df["tip"]), axis=1)

def percentage(total_bill, tip):
    if total_bill / tip > 2 :
        return "OK"
    else:
        return "NOT-OK"

df["percentage"] = np.vectorize(percentage)(df["total_bill"], df["tip"])

# timeit.timeit() Tool for measuring execution time of small code snippets.
    setup = """
    import numpy as np
    import pandas as pd
    df = pd.read_csv("tips.csv")
    def percentage(total_bill, tip):
        if total_bill / tip > 2 :
            return "OK"
        else:
            return "NOT-OK"
    """

    stmt_one = """df[["total_bill", "tip"]].apply(lambda df: percentage(df["total_bill"], df["tip"]), axis=1)"""
    stmt_two = """df["percentage"] = np.vectorize(percentage)(df["total_bill"], df["tip"])"""

    timeit.timeit(setup=setup, stmt=stmt_one, number=1000)

    timeit.timeit(setup=setup, stmt=stmt_two, number=1000)

df.describe().transpose()
df.sort_values("tip")
df.sort_values("tip", ascending=False).head()
df.sort_values(["tip", "size"]).head()
df["total_bill"].max()
df["total_bill"].idxmax() # Return the row label (index number) of the maximum value.
df["total_bill"].min()
df["total_bill"].idxmin()
df.iloc[df["total_bill"].idxmin()]
df.corr()
df["sex"].value_counts()
df["day"].unique()
df["day"].nunique()
df["sex"].replace(["Female", "Male"], ["F", "M"])

mymap = {"Female":"F", "Male":"M"}
df["sex"].map(mymap)

df.duplicated()
df.drop_duplicates()

df["total_bill"].between(10,20,inclusive=True)
df[df["total_bill"].between(10,20,inclusive=True)]

df.nlargest(2, "tip") # sorts by tip and shows the max 10
df.sort_values("tip", ascending=False).iloc[0:2]

df.nsmallest(2, "tip")
df.sort_values("tip").iloc[0:2]

df.sample(5) # Select 5
df.sample(frac=0.1) # Select %10 randomly

np.nan
pd.NA
pd.NaT
np.nan == np.nan
np.nan is np.nan

df.isnull()
df.notnull()
df["pre_movie_score"].notnull()
df[df["pre_movie_score"].notnull()]
df[(df["pre_movie_score"].isnull()) & (df["first_name"].notnull())]

df.dropna()
df.dropna(thresh=4) # Keep if row has at least 4 value
df.dropna(axis=1) # Choose axis=0 intead, removes all columns because each calumn has at least 1 NaN
df.dropna(subset=["last_name"]) # Look at the last_name column to remove if it has NaN
df.fillna("NEW DATA")
df["pre_movie_score"].fillna(0) # fill "0" for all NaN temporarly
df["pre_movie_score"] = df["pre_movie_score"].fillna(0) # fill "0" for all NaN permanently
df["pre_movie_score"].fillna(df["pre_movie_score"].mean())
ser.interpolate() # gets the upper and lower values mean, use at first sort!!!

# %%
import numpy as np
import pandas as pd
import timeit

# %%
df = pd.read_csv("tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
123456789[-4:]
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# C:\Users\engin\AppData\Local\Temp\ipykernel_13616\2713480295.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   123456789[-4:]
# C:\Users\engin\AppData\Local\Temp\ipykernel_13616\2713480295.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   123456789[-4:]
# C:\Users\engin\AppData\Local\Temp\ipykernel_13616\2713480295.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   123456789[-4:]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\1_Engin\1_Google_Drive\1_IT_Courses\1_Github_Mine\02_DA\06_DAwPYT\05_BP\10_DAwPYTH_BP_10_(Pandas).ipynb Cell 7' in <cell line: 1>()
# ...

# %%
str(123456789)[-4:]
# Out:
# '6789'

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(123456789)
# Out:
# '6789'

# %%
df["CC Number"].apply(last_four)
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
df["last_four"] = df["CC Number"].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %%
df["CC Number"].mean()
# Out:
# 2563495562019613.0

# %%
def yelp(price):
    if price < 10:
        return "$"
    elif price >= 10 and price < 30:
        return "$$"
    else:
        return "$$$"

# %%
df["yelp"] = df["tip"].apply(yelp)

# %%
df[df["yelp"] == "$"].value_counts().sum()
# Out:
# 243

# %%
df[df["yelp"] == "$$"].value_counts().sum()
# Out:
# 1

# %%
df[df["yelp"] == "$$$"].value_counts().sum()
# Out:
# 0

# %%
df = pd.read_csv("tips.csv")

# %%
def simple(num):
    return num*2

# %%
simple(4)
# Out:
# 8

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df["tip"].apply(simple)
# Out:
# 0       2.02
# 1       3.32
# 2       7.00
# 3       6.62
# 4       7.22
#        ...
# 239    11.84
# 240     4.00
# 241     4.00
# 242     3.50
# 243     6.00
# Name: tip, Length: 244, dtype: float64

# %%
df["tip"].apply(lambda num: num*2)
# Out:
# 0       2.02
# 1       3.32
# 2       7.00
# 3       6.62
# 4       7.22
#        ...
# 239    11.84
# 240     4.00
# 241     4.00
# 242     3.50
# 243     6.00
# Name: tip, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def percentage(total_bill, tip):
    print("percentage: ", total_bill / tip)
    if total_bill / tip > 2 :
        return "OK"
    else:
        return "NOT-OK"

# %%
percentage(22.0, 7.2500)
# Out:
# percentage:  3.0344827586206895
# 'OK'

# %%
df[["total_bill", "tip"]].apply(lambda df: percentage(df["total_bill"], df["tip"]), axis=1)
# Out:
# percentage:  16.82178217821782
# percentage:  6.228915662650603
# percentage:  6.002857142857144
# percentage:  7.1540785498489425
# percentage:  6.811634349030471
# percentage:  5.369426751592356
# percentage:  4.385
# percentage:  8.615384615384615
# percentage:  7.673469387755102
# percentage:  4.575851393188854
# percentage:  6.005847953216374
# percentage:  7.052
# percentage:  9.821656050955413
# percentage:  6.1433333333333335
# percentage:  4.910596026490066
# percentage:  5.505102040816326
# percentage:  6.185628742514971
# percentage:  4.390835579514825
# percentage:  4.848571428571428
# percentage:  6.164179104477611
# percentage:  4.392156862745098
# percentage:  7.378181818181818
# percentage:  7.071748878923767
# percentage:  5.200527704485489
# percentage:  6.232704402515723
# percentage:  7.611111111111111
# percentage:  6.685
# percentage:  6.345
# percentage:  5.046511627906977
# percentage:  6.55
# percentage:  6.586206896551725
# percentage:  7.340000000000001
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def percentage(total_bill, tip):
    if total_bill / tip > 2 :
        return "OK"
    else:
        return "NOT-OK"

# %%
df["percentage"] = np.vectorize(percentage)(df["total_bill"], df["tip"])
df["percentage"]
# Out:
# 0      OK
# 1      OK
# 2      OK
# 3      OK
# 4      OK
#        ..
# 239    OK
# 240    OK
# 241    OK
# 242    OK
# 243    OK
# Name: percentage, Length: 244, dtype: object

# %%
setup = """
import numpy as np
import pandas as pd
df = pd.read_csv("tips.csv")
def percentage(total_bill, tip):
    if total_bill / tip > 2 :
        return "OK"
    else:
        return "NOT-OK"
"""

# %%
stmt_one = """df[["total_bill", "tip"]].apply(lambda df: percentage(df["total_bill"], df["tip"]), axis=1)"""
stmt_two = """df["percentage"] = np.vectorize(percentage)(df["total_bill"], df["tip"])"""

# %%
timeit.timeit(setup=setup, stmt=stmt_one, number=1000)
# Out:
# 6.607671200006735

# %%
timeit.timeit(setup=setup, stmt=stmt_two, number=1000)
# Out:
# 0.571163799992064

# %%
# ------------------Describing and Sorting-------------------

# %%
df = pd.read_csv("tips.csv")

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.sort_values("tip").head()
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 236       Matthew Myers  3543676378973965    Sat5032
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 0    Christy Cunningham  3560325168603410    Sun2959

# %%
df.sort_values("tip", ascending=False).head()
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.sort_values(["tip", "size"]).head()
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 111         Terri Jones  3559221007826887    Sat4801
# 92         Leah Ramirez  3508911676966392    Fri3780
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# en yüksek total_bill
df["total_bill"].max()
# Out:
# 50.81

# %%
# en yüksek total_billin index numarası
df["total_bill"].idxmax()
# Out:
# 170

# %%
# en yüksek total_billin index numarasına karşılık gelen satır bilgileri
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
# en düşük total_bill
df["total_bill"].min()
# Out:
# 3.07

# %%
# en düşük total_billin index numarası
df["total_bill"].idxmin()
# Out:
# 67

# %%
# en düşük total_billin index numarasına karşılık gelen satır bilgileri
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
# yukarıdakinin aynısı
df.iloc[df["total_bill"].idxmin()]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
# sütunların birbirleri ile olan corelationları
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["day"]
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
df["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df["day"].nunique()
# Out:
# 4

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df["sex"].replace(["Female", "Male"], ["F", "M"])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
mymap = {"Female":"F", "Male":"M"}

# %%
df["sex"].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2,2], ["a","b","c","d"])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# 20 dahil olsun istiyorsan inclusive=True
df["total_bill"].between(10,20,inclusive=True)
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_13616\1743531530.py:2: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df["total_bill"].between(10,20,inclusive=True)
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
# True False yerine gerçek değerleri ile gösterir
df[df["total_bill"].between(10,20,inclusive=True)]
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_13616\1918572440.py:2: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df["total_bill"].between(10,20,inclusive=True)]
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# ...

# %%
# "tip" sütununa göre sort ediyor ve en üstte yer alan 10 satırı gösteriyor
df.nlargest(10, "tip")
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# ...

# %%
# "tip" sütununa göre sort ediyor ve en üstte yer alan 2 satırı gösteriyor
df.nlargest(2, "tip")
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
# sort_values ve iloc ile de aynısını yapabiliriz.
df.sort_values("tip", ascending=False).iloc[0:2]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
# "tip" sütununa göre sort ediyor ve en üstte yer alan 10 satırı gösteriyor
df.nsmallest(10, "tip")
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# ...

# %%
# "tip" sütununa göre sort ediyor ve en üstte yer alan 2 satırı gösteriyor
df.nsmallest(2, "tip")
# Out:
#     total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
#
#        Payer Name         CC Number Payment ID
# 67  Tiffany Brock  4359488526995267    Sat3455
# 92   Leah Ramirez  3508911676966392    Fri3780

# %%
# sort_values ve iloc ile de aynısını yapabiliriz.
df.sort_values("tip").iloc[0:2]
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2              6.30
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 236  Matthew Myers  3543676378973965    Sat5032

# %%
# random olarak 5 satır getirdi her run da farklı çalışır
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 78        22.76  3.00    Male     No  Thur   Lunch     2             11.38
# 163       13.81  2.00    Male     No   Sun  Dinner     2              6.90
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 5         25.29  4.71    Male     No   Sun  Dinner     4              6.32
# 99        12.46  1.50    Male     No   Fri  Dinner     2              6.23
#
#          Payer Name         CC Number Payment ID
# 78       Chris Hahn  3591887177014031   Thur2863
# 163  Charles Newton  5552793481414044    Sun8594
# 203     Toni Brooks  3582289985920239   Thur7770
# 5        Erik Smith   213140353657882    Sun9679
# 99    Edward Carter   347435564751626    Fri5575

# %%
# tablonun %10 nu random seç demek
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2              8.94
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3              8.86
# 139       13.16  2.75  Female     No  Thur   Lunch     2              6.58
# 86        13.03  2.00    Male     No  Thur   Lunch     2              6.52
# 25        17.81  2.34    Male     No   Sat  Dinner     4              4.45
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2             14.48
# 137       14.15  2.00  Female     No  Thur   Lunch     2              7.08
# 32        15.06  3.00  Female     No   Sat  Dinner     2              7.53
# 45        18.29  3.00    Male     No   Sun  Dinner     2              9.14
# 227       20.45  3.00    Male     No   Sat  Dinner     4              5.11
# 130       19.08  1.50    Male     No  Thur   Lunch     2              9.54
# ...

# %%
# ------------------------Missing Data--------------------

# %%
# Options for missin data
    # Keep it
    # Remove it
    # Replace it

# %%
np.nan
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT
# Out:
# NaT

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
myvar = np.nan

# %%
myvar is np.nan
# Out:
# True

# %%
df = pd.read_csv("movie_scores.csv")

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# Veri varsa False, yoksa True
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
# Veri varsa True, yoksa False
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
# pre_movie_score daki veri varsa True yoksa False
df["pre_movie_score"].notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: pre_movie_score, dtype: bool

# %%
# pre_movie_score daki veri olanları gösterir
df[df["pre_movie_score"].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[df["pre_movie_score"].isnull()]
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN

# %%
# pre_movie_score boş veri olan ve aynı zamanda first_name de veri olanları göster
df[(df["pre_movie_score"].isnull()) & (df["first_name"].notnull())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %%
# Keep it
# Drop it
# Fill it

# %%
# Keep it
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# Drop it
# Aşağıdaki alandan help alabilirsin
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis: 'Axis' = 0, how: 'str' = 'any', thresh=None, subset: 'IndexLabel' = None, inplace: 'bool' = False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. versionchanged:: 1.0.0
#
#            Pass tuple or list to drop on multiple axes.
#            Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
# ...

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# Tüm missing valuelar gider
df.dropna()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# En az 4 adet value varsa tut. mesela 5 yaparsak Hugh satırı da gider
df.dropna(thresh=4)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# Tüm sütunlarda en az 1 adet NaN olduğundan tüm sütunları siler
# Bu nedenle axis = 0 yapmak genel olarak tercih edilmeli
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# İlgili sütuna bak False olanları çıkar
# Tresh ile birlikte kullanılırsa daha iyi olur
df.dropna(subset=["last_name"])
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# Filling İT

# %%
# Buradan bilgi alabilirsin
help(df.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value: 'object | ArrayLike | None' = None, method: 'FillnaOptions | None' = None, axis: 'Axis | None' = None, inplace: 'bool' = False, limit=None, downcast=None) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method.
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame).  Values not
#         in the dict/Series/DataFrame will not be filled. This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series
#         pad / ffill: propagate last valid observation forward to next valid
# ...

# %%
# Tüm NaN olanları tek seferde bu şekilde değiştirebilirsin
df.fillna("NEW DATA")
# Out:
#   first_name last_name       age       sex pre_movie_score post_movie_score
# 0        Tom     Hanks      63.0         m             8.0             10.0
# 1   NEW DATA  NEW DATA  NEW DATA  NEW DATA        NEW DATA         NEW DATA
# 2       Hugh   Jackman      51.0         m        NEW DATA         NEW DATA
# 3      Oprah   Winfrey      66.0         f             6.0              8.0
# 4       Emma     Stone      31.0         f             7.0              9.0

# %%
# Bir sütundaki NaN olanları belli bir int ile doldurabilirsin
# Geçici yapar
df["pre_movie_score"].fillna(0)
# Out:
# 0    8.0
# 1    0.0
# 2    0.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df = pd.read_csv("movie_scores.csv")

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# Kalıcı yapmak için bu kullanılır
df["pre_movie_score"] = df["pre_movie_score"].fillna(0)

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              0.0               NaN
# 2       Hugh   Jackman  51.0    m              0.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df = pd.read_csv("movie_scores.csv")

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# Bu sütundaki boş verilere mean eklemek istedin diyelim
df["pre_movie_score"].mean()
# Out:
# 7.0

# %%
# fonksiyonu direk fillna içine doldurup kurgulayabilirsin
df["pre_movie_score"].fillna(df["pre_movie_score"].mean())
# Out:
# 0    8.0
# 1    7.0
# 2    7.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
airline_tix = {"first":100, "business":np.nan, "economy-plus":50, "economy":30}

# %%
ser = pd.Series(airline_tix)

# %%
ser
# Out:
# first           100.0
# business          NaN
# economy-plus     50.0
# economy          30.0
# dtype: float64

# %%
# Bir alt bir üst rakamların ortalamasını alıp NaN olan alanı doldurur
# Sort ederek kullanmakta fayda var
ser.interpolate()
# Out:
# first           100.0
# business         75.0
# economy-plus     50.0
# economy          30.0
# dtype: float64
