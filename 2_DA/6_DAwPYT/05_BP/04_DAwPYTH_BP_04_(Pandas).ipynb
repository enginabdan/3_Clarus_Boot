# %%
# -----------04_DAwPYTH_BP_04_(Pandas)--------------
# ------------Introduction to Pandas----------------

# %%
# SUMMARY

# data "manipulation" and "analysis"
# "numerical tables" and "time series"
# "machine learning" in form of "DataFrames"
# "importing data" such as "csv, excel" etc
# "groupby, join, merge, melt, concatenation"
# "data cleaning", "filling", "replacing", "imputing null values"
# "Series" and "Data Frames"
# "Conditional Filtering"
# "Missing Data"
# Text Methods and Time Methods
# Numpy index >>> numeric
# Pandas index >>> labeled

# %%
# The name of Pandas is derived from the word "Panel Data",
# which means an "Econometrics" from "Multidimensional data"
# developed by "Wes McKinney" in "2008"

# %%
# for data "manipulation" and "analysis"
# manipulating "numerical tables" and "time series"
# mainly used for "machine learning" in form of "DataFrames"
# allows "importing data" of various file formats such as "csv, excel" etc
# "groupby, join, merge, melt, concatenation"
# as well as "data cleaning" features such as "filling, replacing or imputing null values"

# %%
# Series and Data Frames
# Conditional Filtering and Useful Methods
# Missing Data
# Group By Operations
# Combining DataFrames
# Text Methods and Time Methods
# Inputs and Outputs

# %%
# Numpy index is numeric
# Pandas index is labeled
