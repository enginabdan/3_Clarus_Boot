# %%
# -----------05_DAwPYTH_BP_05_(Pandas)--------------
# --------------------Series------------------------

# %%
# SUMMARY

myser = pd.Series(data=mydata)
myser = pd.Series(data=mydata, index=myindex)
myser = pd.Series(mydata, myindex)
myser[0]
myser["USA"]
ages = {"engin":39, "azra":40, "neda":13, "aden":4}
sales_q1.keys()
["a","b","c"] * 2
np.array(["a","b","c"]) * 2
sales_q1.add(sales_q2, fill_value=0)
sales_q1.div(sales_q2, fill_value=0)
sales_q1.mul(sales_q2, fill_value=0)
sales_q1.sub(sales_q2, fill_value=0)

# %%
import numpy as np
import pandas as pd

# %%
# help(pd.Series)

# %%
myindex = ["USA", "Canada", "Mexico"]

# %%
mydata = ["1776", "1867", "1821"]

# %%
myser = pd.Series(data=mydata)

# %%
myser
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: object

# %%
type(myser)
# Out:
# pandas.core.series.Series

# %%
myser = pd.Series(data=mydata, index=myindex)

# %%
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: object

# %%
type(myser)
# Out:
# pandas.core.series.Series

# %%
myser[0]
# Out:
# '1776'

# %%
myser["USA"]
# Out:
# '1776'

# %%
myser = pd.Series(mydata, myindex)
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: object

# %%
ages = {"engin":39, "azra":40, "neda":13, "aden":4}

# %%
pd.Series(ages)
# Out:
# engin    39
# azra     40
# neda     13
# aden      4
# dtype: int64

# %%
expenses = pd.Series({'Andrew':200,'Bob':150,'Claire':450})
bob_expense = expenses["Bob"]
bob_expense
# Out:
# 150

# %%
dict = {'x':10,'y':20}
pd.Series(dict)
# Out:
# x    10
# y    20
# dtype: int64

# %%
ages = {"Sam":5, "Frank":10, "Spike":7}
pd.Series(ages)
# Out:
# Sam       5
# Frank    10
# Spike     7
# dtype: int64

# %%
q1 = {"Japan":80, "China":450, "India":200, "USA":250}
q2 = {"Brazil":100, "China":500, "India":210, "USA":260}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
sales_q1["Japan"]
# Out:
# 80

# %%
sales_q1[0]
# Out:
# 80

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
["a","b","c"] * 2
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c']

# %%
[1,2] * 2
# Out:
# [1, 2, 1, 2]

# %%
w = np.array(([1,2], [3,4]))
w
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
w * 2
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
sales_q1 * 2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_q1 / 100
# Out:
# Japan    0.8
# China    4.5
# India    2.0
# USA      2.5
# dtype: float64

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
# normal toplamada her 2 yerde de olmayanlara NaN atıyor
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
# burada "add", "div", "mul", "sub" kullanacağız 
# herhangi bir işlemde float olacak
y = sales_q1.add(sales_q2, fill_value=0)
y
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
y = sales_q1.div(sales_q2, fill_value=0)
y
# Out:
# Brazil    0.000000
# China     0.900000
# India     0.952381
# Japan          inf
# USA       0.961538
# dtype: float64

# %%
y = sales_q1.mul(sales_q2, fill_value=0)
y
# Out:
# Brazil         0.0
# China     225000.0
# India      42000.0
# Japan          0.0
# USA        65000.0
# dtype: float64

# %%
y = sales_q1.sub(sales_q2, fill_value=0)
y
# Out:
# Brazil   -100.0
# China     -50.0
# India     -10.0
# Japan      80.0
# USA       -10.0
# dtype: float64

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q1.dtype
# Out:
# dtype('int64')

# %%
a = sales_q1.add(sales_q2, fill_value=0)
a
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
a.dtype
# Out:
# dtype('float64')
