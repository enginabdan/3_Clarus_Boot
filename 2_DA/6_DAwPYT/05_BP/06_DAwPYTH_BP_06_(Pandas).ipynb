# %%
# -----------06_DAwPYTH_BP_06_(Pandas)--------------
# ----Attributes, Indexing, Column Creating---------

# %%
# SUMMARY

df = pd.DataFrame(data=mydata, index=myindex, columns=mycolums)
df = pd.DataFrame(mydata, myindex, mycolums)
df.info()
df.shape
pwd
ls
df = pd.read_csv("D:\\1_Engin\\1_Google_Drive\\1_IT_Courses\\1_Github_Mine\\02_DA\\06_DAwPYT\\05_BP\\titanic.csv")
df = pd.read_csv("titanic.csv") # absolute path / relative path

# %%
# DataFrame
    # two-dimensional data structure
    # rows and columns.
    
    # Three principal components;
        # the data,
        # rows,
        # columns form the Pandas DataFrame.

# %%
# The columns can be "heterogeneous" types like int and bool.
# can be seen as a dictionary of Series structure where both the rows and columns are indexed.
# It is denoted as "columns" in the case of columns and "index" in case of rows.

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101) # For the same values
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ["CA","NY","AZ","TX"]

# %%
mycolums = ["Jan","Feb","Mar"]

# %%
df = pd.DataFrame(mydata)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=mydata)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=mydata, index=myindex)
df
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df = pd.DataFrame(data=mydata, index=myindex, columns=mycolums)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df = pd.DataFrame(mydata, myindex, mycolums)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
pwd
# Out:
# 'd:\\1_Engin\\1_Google_Drive\\1_IT_Courses\\1_Github_Mine\\02_DA\\06_DAwPYT\\05_BP'

# %%
ls
# Out:
#  Volume in drive D is Yeni Birim
#  Volume Serial Number is 5A32-FC83
#
#  Directory of d:\1_Engin\1_Google_Drive\1_IT_Courses\1_Github_Mine\02_DA\06_DAwPYT\05_BP
#
# 01-Apr-22  20:42    <DIR>          .
# 01-Apr-22  20:42    <DIR>          ..
# 01-Apr-22  15:09            19,735 01_DAwPYTH_BP_01_(Numpy).ipynb
# 01-Apr-22  15:09            13,695 02_DAwPYTH_BP_02_(Numpy).ipynb
# 01-Apr-22  15:09            13,194 03_DAwPYTH_BP_03_(Numpy).ipynb
# 01-Apr-22  15:15             2,772 04_DAwPYTH_BP_04_(Pandas).ipynb
# 01-Apr-22  15:16            11,628 05_DAwPYTH_BP_05_(Pandas).ipynb
# 01-Apr-22  20:33            19,696 06_DAwPYTH_BP_06_(Pandas).ipynb
# 28-Jun-21  16:52            35,384 07_DAwPYTH_BP_07_(Pandas).ipynb
# 28-Jun-21  16:52           225,398 08_DAwPYTH_BP_08_(Pandas).ipynb
# 28-Jun-21  16:51           182,283 09_DAwPYTH_BP_09_(Pandas).ipynb
# 29-Jun-21  02:02           154,000 10_DAwPYTH_BP_10_(Pandas).ipynb
# ...

# %%
# df = pd.read_csv("titanic.csv") olarak da yazabilirsin absolute/relative path!!!
df = pd.read_csv("D:\\1_Engin\\1_Google_Drive\\1_IT_Courses\\1_Github_Mine\\02_DA\\06_DAwPYT\\05_BP\\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
