# %%
# -----------03_DAwPYT_BL_03--------------

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("adult.data.csv")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
def val_count(data):
    for i in data.columns:
        print(i)
        print(data[i].value_counts(dropna=False))
        print(25*"*-", "\n")

# %%
val_count(df)
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: age, Length: 74, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# fnlwgt
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 188488     1
# 285290     1
# 293579     1
# 114874     1
# 257302     1
# Name: fnlwgt, Length: 28523, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# educational-num
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: educational-num, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# gender
# Male      32650
# Female    16192
# Name: gender, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# capital-gain
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
#          ...
# 1111         1
# 7262         1
# 22040        1
# 1639         1
# 2387         1
# Name: capital-gain, Length: 123, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# capital-loss
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
#         ...
# 2465        1
# 2080        1
# 155         1
# 1911        1
# 2201        1
# Name: capital-loss, Length: 99, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# hours-per-week
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
#       ...
# 69        1
# 87        1
# 94        1
# 82        1
# 79        1
# Name: hours-per-week, Length: 96, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# income
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-

# %%
unknown_wrkcls = df["workclass"] == "?"
unknown_wrkcls
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: workclass, Length: 48842, dtype: bool

# %%
df[unknown_wrkcls]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18         ?  103497  Some-college               10
# 6       29         ?  227026       HS-grad                9
# 13      58         ?  299831       HS-grad                9
# 22      72         ?  132015       7th-8th                4
# 35      65         ?  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35         ?  320084     Bachelors               13
# 48812   30         ?   33811     Bachelors               13
# 48820   71         ?  287372     Doctorate               16
# 48822   41         ?  202822       HS-grad                9
# 48823   72         ?  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married          ?      Own-child               White
# 6           Never-married          ?      Unmarried               Black
# 13     Married-civ-spouse          ?        Husband               White
# 22               Divorced          ?  Not-in-family               White
# 35     Married-civ-spouse          ?        Husband               White
# ...                   ...        ...            ...                 ...
# 48811  Married-civ-spouse          ?           Wife               White
# 48812       Never-married          ?  Not-in-family  Asian-Pac-Islander
# 48820  Married-civ-spouse          ?        Husband               White
# 48822           Separated          ?  Not-in-family               Black
# 48823  Married-civ-spouse          ?        Husband               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 4      Female             0             0              30  United-States
# 6        Male             0             0              40  United-States
# 13       Male             0             0              35  United-States
# 22     Female             0             0               6  United-States
# 35       Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 48811  Female             0             0              55  United-States
# 48812  Female             0             0              99  United-States
# 48820    Male             0             0              10  United-States
# 48822  Female             0             0              32  United-States
# 48823    Male             0             0              25  United-States
#
#       income
# 4      <=50K
# 6      <=50K
# 13     <=50K
# 22     <=50K
# 35     <=50K
# ...      ...
# 48811   >50K
# 48812  <=50K
# 48820   >50K
# 48822  <=50K
# 48823  <=50K
#
# [2799 rows x 15 columns]

# %%
df.loc[unknown_wrkcls, "workclass"] = "Unknown"
df.iloc[[27]]
# Out:
#     age workclass  fnlwgt education  educational-num marital-status  \
# 27   23   Private  134446   HS-grad                9      Separated
#
#            occupation relationship   race gender  capital-gain  capital-loss  \
# 27  Machine-op-inspct    Unmarried  Black   Male             0             0
#
#     hours-per-week native-country income
# 27              54  United-States  <=50K

# %%
unknown_occupation = df["occupation"] == "?"
df[unknown_occupation]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18   Unknown  103497  Some-college               10
# 6       29   Unknown  227026       HS-grad                9
# 13      58   Unknown  299831       HS-grad                9
# 22      72   Unknown  132015       7th-8th                4
# 35      65   Unknown  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35   Unknown  320084     Bachelors               13
# 48812   30   Unknown   33811     Bachelors               13
# 48820   71   Unknown  287372     Doctorate               16
# 48822   41   Unknown  202822       HS-grad                9
# 48823   72   Unknown  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married          ?      Own-child               White
# 6           Never-married          ?      Unmarried               Black
# 13     Married-civ-spouse          ?        Husband               White
# 22               Divorced          ?  Not-in-family               White
# 35     Married-civ-spouse          ?        Husband               White
# ...                   ...        ...            ...                 ...
# 48811  Married-civ-spouse          ?           Wife               White
# 48812       Never-married          ?  Not-in-family  Asian-Pac-Islander
# 48820  Married-civ-spouse          ?        Husband               White
# 48822           Separated          ?  Not-in-family               Black
# 48823  Married-civ-spouse          ?        Husband               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 4      Female             0             0              30  United-States
# 6        Male             0             0              40  United-States
# 13       Male             0             0              35  United-States
# 22     Female             0             0               6  United-States
# 35       Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 48811  Female             0             0              55  United-States
# 48812  Female             0             0              99  United-States
# 48820    Male             0             0              10  United-States
# 48822  Female             0             0              32  United-States
# 48823    Male             0             0              25  United-States
#
#       income
# 4      <=50K
# 6      <=50K
# 13     <=50K
# 22     <=50K
# 35     <=50K
# ...      ...
# 48811   >50K
# 48812  <=50K
# 48820   >50K
# 48822  <=50K
# 48823  <=50K
#
# [2809 rows x 15 columns]

# %%
df.loc[unknown_occupation, "occupation"] = "Unknown"
df.iloc[[27]]
# Out:
#     age workclass  fnlwgt education  educational-num marital-status  \
# 27   23   Private  134446   HS-grad                9      Separated
#
#            occupation relationship   race gender  capital-gain  capital-loss  \
# 27  Machine-op-inspct    Unmarried  Black   Male             0             0
#
#     hours-per-week native-country income
# 27              54  United-States  <=50K

# %%
unknown_country = df["native-country"] == "?"
df[unknown_country]
# Out:
#        age         workclass  fnlwgt  education  educational-num  \
# 19      40           Private   85019  Doctorate               16
# 65      41           Private  109912  Bachelors               13
# 83      44      Self-emp-inc  223881    HS-grad                9
# 188     34         State-gov  513100  Bachelors               13
# 253     42       Federal-gov  177937  Bachelors               13
# ...    ...               ...     ...        ...              ...
# 48730   44      Self-emp-inc   71556    Masters               14
# 48750   58      Self-emp-inc  181974  Doctorate               16
# 48773   42  Self-emp-not-inc  217597    HS-grad                9
# 48791   39           Private  107302    HS-grad                9
# 48806   81           Unknown  120478  Assoc-voc               11
#
#               marital-status       occupation   relationship  \
# 19        Married-civ-spouse   Prof-specialty        Husband
# 65             Never-married    Other-service  Not-in-family
# 83        Married-civ-spouse     Craft-repair        Husband
# 188    Married-spouse-absent  Farming-fishing  Not-in-family
# 253            Never-married   Prof-specialty  Not-in-family
# ...                      ...              ...            ...
# 48730     Married-civ-spouse            Sales        Husband
# 48750          Never-married   Prof-specialty  Not-in-family
# 48773               Divorced            Sales      Own-child
# 48791     Married-civ-spouse   Prof-specialty        Husband
# 48806               Divorced          Unknown      Unmarried
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 19     Asian-Pac-Islander    Male             0             0              45
# 65                  White  Female             0             0              40
# 83                  White    Male         99999             0              50
# 188                 Black    Male             0             0              40
# 253                 White    Male             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48730               White    Male             0             0              50
# 48750               White  Female             0             0              99
# 48773               White    Male             0             0              50
# 48791               White    Male             0             0              45
# 48806               White  Female             0             0               1
#
#       native-country income
# 19                 ?   >50K
# 65                 ?  <=50K
# 83                 ?   >50K
# 188                ?  <=50K
# 253                ?  <=50K
# ...              ...    ...
# 48730              ?   >50K
# 48750              ?  <=50K
# 48773              ?  <=50K
# 48791              ?   >50K
# 48806              ?  <=50K
#
# [857 rows x 15 columns]

# %%
df.loc[unknown_country, "native-country"] = "Unknown"
df.iloc[[14]]
# Out:
#     age workclass  fnlwgt education  educational-num      marital-status  \
# 14   48   Private  279724   HS-grad                9  Married-civ-spouse
#
#            occupation relationship   race gender  capital-gain  capital-loss  \
# 14  Machine-op-inspct      Husband  White   Male          3103             0
#
#     hours-per-week native-country income
# 14              48  United-States   >50K

# %%
def replacer(df, value, subtitude):
    for i in df.columns:
        if df[i].isin([value]).any():
            print(i, "Column has changed")
            unknown = df[i] == value
            df.loc[unknown, i] = subtitude
replacer(df, "?", "Unknown")

# %%
for i in df.columns:
    df[i].replace("?", "Unknown")

# %%
df.groupby("education")["educational-num"].value_counts()
# Out:
# education     educational-num
# 10th          6                   1389
# 11th          7                   1812
# 12th          8                    657
# 1st-4th       2                    247
# 5th-6th       3                    509
# 7th-8th       4                    955
# 9th           5                    756
# Assoc-acdm    12                  1601
# Assoc-voc     11                  2061
# Bachelors     13                  8025
# Doctorate     16                   594
# HS-grad       9                  15784
# Masters       14                  2657
# Preschool     1                     83
# Prof-school   15                   834
# Some-college  10                 10878
# Name: educational-num, dtype: int64

# %%
df["educational-num"].value_counts()
# Out:
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: educational-num, dtype: int64

# %%
df.drop("educational-num", axis=1, inplace=True)

# %%
df.shape
# Out:
# (48842, 14)

# %%
df.isnull().any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# gender            False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# income            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# gender            0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076628      0.077229      0.056944        0.071558
# fnlwgt         -0.076628  1.000000     -0.003706     -0.004366       -0.013519
# capital-gain    0.077229 -0.003706      1.000000     -0.031441        0.082157
# capital-loss    0.056944 -0.004366     -0.031441      1.000000        0.054467
# hours-per-week  0.071558 -0.013519      0.082157      0.054467        1.000000

# %%
df.describe(include="all")
# Out:
#                  age workclass        fnlwgt education      marital-status  \
# count   48842.000000     48842  4.884200e+04     48842               48842
# unique           NaN         9           NaN        16                   7
# top              NaN   Private           NaN   HS-grad  Married-civ-spouse
# freq             NaN     33906           NaN     15784               22379
# mean       38.643585       NaN  1.896641e+05       NaN                 NaN
# std        13.710510       NaN  1.056040e+05       NaN                 NaN
# min        17.000000       NaN  1.228500e+04       NaN                 NaN
# 25%        28.000000       NaN  1.175505e+05       NaN                 NaN
# 50%        37.000000       NaN  1.781445e+05       NaN                 NaN
# 75%        48.000000       NaN  2.376420e+05       NaN                 NaN
# max        90.000000       NaN  1.490400e+06       NaN                 NaN
#
#             occupation relationship   race gender  capital-gain  capital-loss  \
# count            48842        48842  48842  48842  48842.000000  48842.000000
# unique              15            6      5      2           NaN           NaN
# top     Prof-specialty      Husband  White   Male           NaN           NaN
# freq              6172        19716  41762  32650           NaN           NaN
# mean               NaN          NaN    NaN    NaN   1079.067626     87.502314
# std                NaN          NaN    NaN    NaN   7452.019058    403.004552
# min                NaN          NaN    NaN    NaN      0.000000      0.000000
# 25%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 50%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 75%                NaN          NaN    NaN    NaN      0.000000      0.000000
# max                NaN          NaN    NaN    NaN  99999.000000   4356.000000
#
#         hours-per-week native-country income
# count     48842.000000          48842  48842
# unique             NaN             42      2
# top                NaN  United-States  <=50K
# freq               NaN          43832  37155
# mean         40.422382            NaN    NaN
# std          12.391444            NaN    NaN
# min           1.000000            NaN    NaN
# 25%          40.000000            NaN    NaN
# 50%          40.000000            NaN    NaN
# 75%          45.000000            NaN    NaN
# max          99.000000            NaN    NaN

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  48842.000000  4.884200e+04  48842.000000  48842.000000    48842.000000
# mean      38.643585  1.896641e+05   1079.067626     87.502314       40.422382
# std       13.710510  1.056040e+05   7452.019058    403.004552       12.391444
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.175505e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.781445e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.376420e+05      0.000000      0.000000       45.000000
# max       90.000000  1.490400e+06  99999.000000   4356.000000       99.000000

# %%
df[df["age"] >= 78]["age"].value_counts()
# Out:
# 90    55
# 80    38
# 81    37
# 78    34
# 79    30
# 82    15
# 84    13
# 83    11
# 88     6
# 85     5
# 87     3
# 89     2
# 86     1
# Name: age, dtype: int64

# %%
fig, ax = plt.subplots(2,3,figsize=(20,7))
x=0
y=0
for column in df.select_dtypes("number").columns:
    df[column].plot(kind="box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[df["age"] >= 78].describe()
# Out:
#               age         fnlwgt  capital-gain  capital-loss  hours-per-week
# count  250.000000     250.000000    250.000000     250.00000      250.000000
# mean    82.888000  158100.256000   1918.060000     117.28800       27.500000
# std      4.408309   88707.684175   9585.754419     558.55601       16.866175
# min     78.000000   20101.000000      0.000000       0.00000        1.000000
# 25%     79.000000   97135.250000      0.000000       0.00000       15.000000
# 50%     81.000000  148846.000000      0.000000       0.00000       25.000000
# 75%     87.750000  197086.500000      0.000000       0.00000       40.000000
# max     90.000000  562336.000000  99999.000000    4356.00000       99.000000

# %%
df[df["age"] >= 78].sample(20)
# Out:
#        age         workclass  fnlwgt    education      marital-status  \
# 8427    90       Federal-gov  311184      Masters            Divorced
# 19818   81  Self-emp-not-inc  137018      HS-grad             Widowed
# 21871   78           Unknown  363134      HS-grad             Widowed
# 11328   83  Self-emp-not-inc  243567         11th       Never-married
# 22513   90  Self-emp-not-inc  155981    Bachelors  Married-civ-spouse
# 21553   90           Private  141758          9th       Never-married
# 33786   78           Unknown   91534    Bachelors  Married-civ-spouse
# 6757    81           Private   36147  Prof-school  Married-civ-spouse
# 22454   79           Private  120707    Doctorate  Married-civ-spouse
# 29111   81           Private  201398      Masters             Widowed
# 9081    80           Unknown  402748      HS-grad             Widowed
# 16711   80           Unknown  107762      HS-grad             Widowed
# 29307   79           Unknown  100881   Assoc-acdm  Married-civ-spouse
# 21572   80           Private  157778      Masters             Widowed
# 10735   90         Local-gov  188242      HS-grad       Never-married
# 17199   81  Self-emp-not-inc  136063      HS-grad  Married-civ-spouse
# 33182   80  Self-emp-not-inc  101771         11th  Married-civ-spouse
# 36702   82           Private  147729      5th-6th             Widowed
# 9888    81           Private  192813      7th-8th  Married-civ-spouse
# 11871   90           Unknown   50746         10th            Divorced
#
#               occupation   relationship   race  gender  capital-gain  \
# 8427      Prof-specialty  Not-in-family  White    Male             0
# 19818       Adm-clerical  Not-in-family  White  Female             0
# 21871            Unknown  Not-in-family  White  Female             0
# 11328    Farming-fishing  Not-in-family  White    Male             0
# 22513     Prof-specialty        Husband  White    Male         10566
# 21553       Adm-clerical  Not-in-family  White  Female             0
# 33786            Unknown        Husband  White    Male             0
# 6757     Farming-fishing        Husband  White    Male         10605
# 22454     Prof-specialty        Husband  White    Male         20051
# 29111     Prof-specialty      Unmarried  White    Male             0
# 9081             Unknown  Not-in-family  White  Female             0
# 16711            Unknown  Not-in-family  White    Male             0
# 29307            Unknown           Wife  White  Female             0
# 21572     Prof-specialty  Not-in-family  White  Female             0
# 10735       Craft-repair      Own-child  White    Male         11678
# 17199    Exec-managerial        Husband  White    Male             0
# 33182    Exec-managerial        Husband  White    Male             0
# 36702      Other-service      Unmarried  White    Male             0
# 9888   Handlers-cleaners        Husband  White    Male             0
# 11871            Unknown  Not-in-family  White  Female             0
#
#        capital-loss  hours-per-week native-country income
# 8427              0              99  United-States  <=50K
# 19818             0              20  United-States  <=50K
# 21871             0               1  United-States  <=50K
# 11328             0              20  United-States  <=50K
# 22513             0              50  United-States  <=50K
# 21553             0              40  United-States  <=50K
# 33786             0               3  United-States  <=50K
# 6757              0               2  United-States   >50K
# 22454             0              35    El-Salvador   >50K
# 29111             0              60        Unknown  <=50K
# 9081              0              14         Canada  <=50K
# 16711             0              24  United-States  <=50K
# 29307             0               2  United-States   >50K
# 21572             0              10  United-States  <=50K
# 10735             0              40  United-States   >50K
# 17199             0              30  United-States  <=50K
# 33182             0              25  United-States  <=50K
# 36702             0              20  United-States  <=50K
# 9888              0              25       Portugal  <=50K
# 11871             0               7  United-States  <=50K

# %%
df[(df["hours-per-week"] == 99)].sample(20)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 46032   51  Self-emp-not-inc   32372          12th  Married-civ-spouse
# 30874   27           Private  179915     Bachelors       Never-married
# 46270   43         Local-gov  118853  Some-college  Married-civ-spouse
# 36012   34       Federal-gov  345259     Doctorate       Never-married
# 42877   35           Private  297574    Assoc-acdm  Married-civ-spouse
# 1121    31         Local-gov  378426   Prof-school  Married-civ-spouse
# 42919   55  Self-emp-not-inc  185195     Bachelors  Married-civ-spouse
# 33273   19           Private  121074       7th-8th  Married-civ-spouse
# 41635   65           Private   89681       Masters       Never-married
# 42531   36  Self-emp-not-inc  257250     Assoc-voc  Married-civ-spouse
# 48750   58      Self-emp-inc  181974     Doctorate       Never-married
# 28906   51           Private  160724     Doctorate  Married-civ-spouse
# 5235    49           Private  107373          10th  Married-civ-spouse
# 34884   33  Self-emp-not-inc   67482     Assoc-voc            Divorced
# 33149   53           Private  178356    Assoc-acdm  Married-civ-spouse
# 13368   42      Self-emp-inc  203233   Prof-school  Married-civ-spouse
# 5099    41  Self-emp-not-inc   34037       HS-grad  Married-civ-spouse
# 6271    35           Private  124090     Assoc-voc  Married-civ-spouse
# 24353   44  Self-emp-not-inc   26669    Assoc-acdm  Married-civ-spouse
# 33892   28  Self-emp-not-inc  104617       7th-8th       Never-married
#
#              occupation    relationship                race  gender  \
# 46032     Other-service         Husband               White    Male
# 30874   Exec-managerial       Own-child               White  Female
# 46270      Tech-support         Husband               White    Male
# 36012    Prof-specialty   Not-in-family               White  Female
# 42877   Exec-managerial         Husband               White    Male
# 1121     Prof-specialty         Husband               White    Male
# 42919   Exec-managerial         Husband               White    Male
# 33273      Craft-repair         Husband               White    Male
# 41635    Prof-specialty   Not-in-family               White    Male
# 42531   Farming-fishing         Husband               White    Male
# 48750    Prof-specialty   Not-in-family               White  Female
# 28906    Prof-specialty         Husband  Asian-Pac-Islander    Male
# 5235   Transport-moving         Husband               White    Male
# 34884     Other-service       Unmarried               White  Female
# 33149   Exec-managerial         Husband               White    Male
# 13368    Prof-specialty         Husband               White    Male
# 5099    Farming-fishing         Husband               White    Male
# 6271   Transport-moving         Husband               White    Male
# 24353     Other-service            Wife               White  Female
# 33892     Other-service  Other-relative               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 46032             0             0              99  United-States  <=50K
# 30874             0             0              99  United-States  <=50K
# 46270          4386             0              99  United-States   >50K
# 36012             0             0              99  United-States  <=50K
# 42877             0             0              99  United-States   >50K
# 1121              0             0              99       Columbia  <=50K
# 42919             0             0              99  United-States  <=50K
# 33273             0             0              99  United-States  <=50K
# 41635             0             0              99  United-States  <=50K
# 42531             0             0              99  United-States  <=50K
# 48750             0             0              99        Unknown  <=50K
# 28906             0             0              99          South  <=50K
# 5235              0             0              99  United-States   >50K
# 34884             0             0              99  United-States  <=50K
# 33149          2407             0              99  United-States  <=50K
# 13368         99999             0              99  United-States   >50K
# 5099              0             0              99  United-States  <=50K
# 6271              0             0              99  United-States  <=50K
# 24353             0             0              99  United-States  <=50K
# 33892             0             0              99         Mexico  <=50K

# %%
df[(df["hours-per-week"] == 99)][["age"]].agg(["median","mean","count"])
# Out:
#                age
# median   42.000000
# mean     44.007299
# count   137.000000

# %%
df[(df["age"] >= 78) & (df["hours-per-week"] == 99)]
# Out:
#        age    workclass  fnlwgt education marital-status        occupation  \
# 8427    90  Federal-gov  311184   Masters       Divorced    Prof-specialty
# 31637   90      Private   90523   HS-grad        Widowed  Transport-moving
#
#         relationship   race gender  capital-gain  capital-loss  \
# 8427   Not-in-family  White   Male             0             0
# 31637      Unmarried  White   Male             0             0
#
#        hours-per-week native-country income
# 8427               99  United-States  <=50K
# 31637              99  United-States  <=50K

# %%
99/7
# Out:
# 14.142857142857142

# %%
df.groupby(by = ["age", "workclass"])["hours-per-week"].agg(["mean", "median", "min", "max", "count"]).loc[90]
# Out:
#                        mean  median  min  max  count
# workclass
# Federal-gov       64.500000    64.5   30   99      2
# Local-gov         40.000000    40.0   20   60      5
# Private           39.114286    40.0   10   99     35
# Self-emp-not-inc  41.400000    45.0   12   60      5
# Unknown           20.750000    12.5    4   40      8

# %%
race_count = df.race.value_counts()
race_count
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %%
average_age_men = df.loc[df["gender"] == "Male", "age"].mean()
average_age_men
# Out:
# 39.49439509954058

# %%
round(average_age_men,1)
# Out:
# 39.5

# %%
df.loc[df["gender"] == "Male", "age"].median()
# Out:
# 38.0

# %%
df.loc[df["gender"] == "Male", "age"].mode()
# Out:
# 0    35
# Name: age, dtype: int64

# %%
df.loc[df["gender"] == "Male", "age"].std()
# Out:
# 13.412849977848172

# %%
plt.figure(figsize=(15,7))
df.loc[df["gender"] == "Male", "age"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
average_age_women = df.loc[df["gender"] == "Female", "age"].mean()
average_age_women
# Out:
# 36.92798913043478

# %%
df.loc[df["gender"] == "Female", "age"].median()
# Out:
# 35.0

# %%
df.loc[df["gender"] == "Female", "age"].mode()
# Out:
# 0    23
# Name: age, dtype: int64

# %%
df.loc[df["gender"] == "Female", "age"].std()
# Out:
# 14.13742261724773

# %%
plt.figure(figsize=(15,7))
df.loc[df["gender"] == "Female", "age"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.groupby("education").education.count()
# Out:
# education
# 10th             1389
# 11th             1812
# 12th              657
# 1st-4th           247
# 5th-6th           509
# 7th-8th           955
# 9th               756
# Assoc-acdm       1601
# Assoc-voc        2061
# Bachelors        8025
# Doctorate         594
# HS-grad         15784
# Masters          2657
# Preschool          83
# Prof-school       834
# Some-college    10878
# Name: education, dtype: int64

# %%
df["education"].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
upper = df.groupby("education").education.count().loc["Bachelors"]
lower = df.groupby("education").education.count().sum()
percentage_bachelors = upper / lower * 100
percentage_bachelors
# Out:
# 16.430531100282543

# %%
df["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.323164
# Some-college    0.222718
# Bachelors       0.164305
# Masters         0.054400
# Assoc-voc       0.042197
# 11th            0.037099
# Assoc-acdm      0.032779
# 10th            0.028439
# 7th-8th         0.019553
# Prof-school     0.017075
# 9th             0.015478
# 12th            0.013452
# Doctorate       0.012162
# 5th-6th         0.010421
# 1st-4th         0.005057
# Preschool       0.001699
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors, 1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %%
df.income.value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
higher_education = (df["education"] == "Bachelors") | (df["education"] == "Masters") | (df["education"] == "Doctorate")
higher_education
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Name: education, Length: 48842, dtype: bool

# %%
df_high_edu = df[higher_education]
df_high_edu
# Out:
#        age    workclass  fnlwgt  education      marital-status  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 19      40      Private   85019  Doctorate  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# ...    ...          ...     ...        ...                 ...
# 48819   38      Private  139180  Bachelors            Divorced
# 48820   71      Unknown  287372  Doctorate  Married-civ-spouse
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# 19      Prof-specialty        Husband  Asian-Pac-Islander    Male
# 20        Tech-support        Husband               White    Male
# 23      Prof-specialty  Not-in-family               White    Male
# ...                ...            ...                 ...     ...
# 48819   Prof-specialty      Unmarried               Black  Female
# 48820          Unknown        Husband               White    Male
# 48825    Other-service  Not-in-family               Other  Female
# 48834     Tech-support  Not-in-family  Asian-Pac-Islander    Male
# 48835  Exec-managerial        Husband               White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 11                0             0              40  United-States  <=50K
# 15                0             0              50  United-States   >50K
# 19                0             0              45        Unknown   >50K
# 20                0             0              47  United-States   >50K
# 23                0             0              43           Peru  <=50K
# ...             ...           ...             ...            ...    ...
# 48819         15020             0              45  United-States   >50K
# 48820             0             0              10  United-States   >50K
# 48825             0             0              30  United-States  <=50K
# 48834             0             0              11         Taiwan  <=50K
# 48835             0             0              40  United-States   >50K
#
# [11276 rows x 14 columns]

# %%
df_high_edu["income"] == ">50K"
# Out:
# 11       False
# 15        True
# 19        True
# 20        True
# 23       False
#          ...
# 48819     True
# 48820     True
# 48825    False
# 48834    False
# 48835     True
# Name: income, Length: 11276, dtype: bool
