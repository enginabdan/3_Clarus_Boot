# %%
# -----------04_DVwPYT_BD_04_(Seaborn)--------------

# %%
# SUMMARY

print(sns.get_dataset_names())  
tips = sns.load_dataset("tips")

# DISTRIBUTIONS : kde, rug, dis, hist
# CATEGORICAL : bar, count, box, swarm, strip, violin
# COMPARISON : joint, pair, cat, matrix, grid

flights_wide = flights.pivot("year", "month", "passengers")

sns.countplot(x="day", data=tips, ax=ax, hue="size") # ax=ax

sns.barplot("day", "tip", data=tips, estimator=np.mean, ci="sd", hue="smoker"); # estimator=np.mean, ci="sd"

sns.barplot(data=tips, x="day", y="total_bill", ax=ax[0], estimator=np.count_nonzero) # np.count_nonzero

sns.boxplot(y="day", x="tip", data=tips, hue="sex", width=0.7) # width=0.7 

sns.violinplot(y="day", x="tip", data=tips, hue="sex", split=True, bw=0.2); # split=True, bw=0.2 

sns.swarmplot(x="total_bill", y="smoker", data=tips, size=10, hue="sex", dodge=True) # dodge=True

sns.boxenplot(y="day", x="tip", data=tips); 

sns.lineplot(data=flights, x="month", y="passengers", hue="year", palette="viridis")

sns.pointplot(data=flights, x="month", y="passengers", hue="year", palette="viridis")

flights_wide = flights.pivot("year", "month", "passengers") # pivot table

# %%
import pandas as pd
import numpy as np

from scipy import stats                 # For statistics

import matplotlib
import matplotlib_inline                # plt.show() yazmamk için
import matplotlib.pyplot as plt
                  
import seaborn as sns
print(sns.get_dataset_names())          # Seaborn Dataset isimlerini çıktı verir

from ipywidgets import interactive      # For interactive styling

import warnings                         # İkazları almamak için
warnings.filterwarnings("ignore")
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
diamonds=sns.load_dataset("diamonds")
exercise=sns.load_dataset("exercise")
flights=sns.load_dataset("flights")
geyser=sns.load_dataset("geyser")
iris=sns.load_dataset("iris")
penguins=sns.load_dataset("penguins")
planets=sns.load_dataset("planets")
mpg=sns.load_dataset("mpg")
tips=sns.load_dataset("tips")
titanic=sns.load_dataset("titanic")

# %%
# ---------------------CATEGORICAL PLOT////COUNTPLOT---------------

# %%
plt.style.use('dark_background')

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(7,4))
sns.countplot(data=tips, x=tips.day);

# %%
fig, ax_tip = plt.subplots()
ax_tip = sns.countplot(x="day", data=tips);

# %%
fig, ax_tip = plt.subplots()
sns.countplot(x="day", data=tips, ax= ax_tip);

# %%
fig, ax_tip = plt.subplots(figsize=(7,5))
ax_tip = sns.countplot(x="day", data=tips)

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+1))
plt.tight_layout();

# %%
sns.countplot(tips["day"]);

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x="day", data=tips, ax=ax, hue="smoker")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+1))
plt.tight_layout();

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x="day", data=tips, ax=ax, hue="size")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+1))
plt.tight_layout();

# %%
fig, ax = plt.subplots(figsize=(7,4))
sns.countplot(x="day", data=tips)

a = (p.get_height())
b = ("%"+str(round((p.get_height()/tips.day.count())*100, 2)))

for p in ax.patches:
    ax.annotate(a, (p.get_x()+0.3, p.get_height()+1))
    ax.annotate(b, (p.get_x()+0.3, p.get_height()-5))
    
plt.tight_layout();

# %%
sns.barplot(tips.sex, tips.tip, data=tips);

# %%
sns.barplot("sex", "tip", data=tips);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.median);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.sum);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.max);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.min);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.mean, ci="sd");

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.mean, ci="sd", hue="smoker");

# %%
sns.barplot("day", "tip", data=tips, estimator=np.mean, ci="sd", hue="smoker");

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(10,4))
sns.barplot(data=tips, x="day", y="total_bill", ax=ax[0], estimator=np.count_nonzero)
sns.countplot(data=tips, x="day", ax=ax[1])
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x="day", y="tip", data=tips);

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x="day", y="tip", data=tips, hue="sex");

# %%
plt.figure(figsize=(7,4))
sns.boxplot(y="day", x="tip", data=tips, hue="sex");

# %%
plt.figure(figsize=(7,4))
sns.boxplot(y="day", x="tip", data=tips, hue="sex", width=0.7);

# %%
plt.figure(figsize=(7,4))
sns.boxplot(y="day", x="tip", data=tips, hue="sex", width=0.7)
plt.legend(loc=4);

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x="day", y="tip", data=tips, hue="sex");

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x="day", y="tip", data=tips, hue="sex", split=True);

# %%
plt.figure(figsize=(8,5))
sns.violinplot(y="day", x="tip", data=tips, hue="sex", split=True);

# %%
plt.figure(figsize=(8,5))
sns.violinplot(y="day", x="tip", data=tips, hue="sex", split=True, bw=0.2);

# %%
plt.figure(figsize=(10,4))
sns.swarmplot(x="total_bill", y="smoker", data=tips, size=10, hue="sex")
plt.legend(loc=2);

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="total_bill", y="smoker", data=tips, size=10, hue="sex", dodge=True)
plt.legend(loc=2);

# %%
plt.figure(figsize=(7,4))
sns.boxenplot(x="day", y="tip", data=tips);

# %%
plt.figure(figsize=(7,4))
sns.boxenplot(y="day", x="tip", data=tips);

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
plt.figure(figsize=(7,4))
sns.lineplot("year", "passengers", data=flights);

# %%
flights.groupby(["year", "month"]).sum().head()
# Out:
#             passengers
# year month
# 1949 Jan           112
#      Feb           118
#      Mar           132
#      Apr           129
#      May           121

# %%
plt.figure(figsize=(7,4))
sns.lineplot(y=flights.passengers.values, x=flights.index);

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_wide = flights.pivot("year", "month", "passengers")
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=flights_wide);

# %%
plt.figure(figsize=(7,4))
sns.lineplot(data=flights, x="month", y="passengers", hue="year")
plt.legend(loc=(1.1,.0));

# %%
plt.figure(figsize=(7,4))
sns.lineplot(data=flights, x="month", y="passengers", hue="year", palette="viridis")
plt.legend(loc=(1.1,.0));

# %%
plt.figure(figsize=(7,4))
sns.pointplot(data=flights, x="month", y="passengers", hue="year", palette="viridis")
plt.legend(loc=(1.1,.0))
