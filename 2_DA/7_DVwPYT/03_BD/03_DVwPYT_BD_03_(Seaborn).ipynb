# %%
# -----------03_DVwPYT_BD_03_(Seaborn)--------------

# %%
# SUMMARY

plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex", palette="plasma", alpha=0.4, s=200);
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# DISTRIBUTIONS : kde, rug,dis,hist
# CATEGORICAL : bar, count, box, swarm, strip, violin
# COMPARISON : joint, pair, cat, matrix, grid

sns.rugplot(data=mpg, x="weight", height=0.5); # height ve alpha 0 ile 1 arasında değer alıyor

sns.histplot(data=mpg, x="weight");

sns.displot(data=mpg, x="weight");

# displot hiçbir zaman bir axese girmez
fig, ax = plt.subplots(1,2,figsize=(8,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", s=200, hue="sex", ax=ax[0])
sns.displot(data=mpg, x="weight", ax=ax[1])
plt.tight_layout;

sns.kdeplot(data=penguins, x="body_mass_g", hue="sex", shade=True);

# http://seaborn.pydata.org/examples/
# bu siteden örnek kodları ve grafik yapılarını görebilirsin

plt.figure(figsize=(7,4))
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter");
# yanda hep histplot var içine kind dan yeni grafik çizdirebilirsin
# KIND OLARAK: scatter, kde, hist, hex, reg, resid

plt.figure(figsize=(7,4))
markers={"Male":">", "Female":"<"}
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex", s=150, markers=markers)
plt.show()
# https://matplotlib.org/stable/api/markers_api.html

# %%
import pandas as pd
import numpy as np

from scipy import stats                 # For statistics

import matplotlib
import matplotlib_inline                # plt.show() yazmamk için
import matplotlib.pyplot as plt
                  
import seaborn as sns
print(sns.get_dataset_names())          # Seaborn Dataset isimlerini çıktı verir

from ipywidgets import interactive      # For interactive styling

import warnings                         # İkazları almamak için
warnings.filterwarnings("ignore")
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
diamonds=sns.load_dataset("diamonds")
exercise=sns.load_dataset("exercise")
flights=sns.load_dataset("flights")
geyser=sns.load_dataset("geyser")
iris=sns.load_dataset("iris")
penguins=sns.load_dataset("penguins")
planets=sns.load_dataset("planets")
mpg=sns.load_dataset("mpg")
tips=sns.load_dataset("tips")
titanic=sns.load_dataset("titanic")

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]

salary_2 = [45372, 48876, 53850, 57287, 63016, 65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.style.use("dark_background")

# %% [markdown]
# ### Functional Method

# %%
plt.plot(age, salary)
plt.xlabel("age")
plt.ylabel("salary")
plt.title("Salary by Age");
plt.show()

# %%
# Object Oriented methot
fig, ax = plt.subplots()
ax.plot(age,salary, 'r')
ax.set_xlabel("age")
ax.set_ylabel('salary')
ax.set_title("Salary by Age")
plt.show()

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig, ax = plt.subplots(figsize=(7,4))
sns.scatterplot(tips.total_bill, tips.tip, data=tips, hue="sex", size=200, style="sex")
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="smoker")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex")
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(10,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex", ax=ax[0])
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", ax=ax[1])
plt.tight_layout();

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex", palette="plasma");
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", palette="plasma", size="sex");

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex", palette="plasma", alpha=0.2);

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex", palette="plasma", alpha=0.4, s=200);

# %%
# DISTRIBUTIONS : kde, rug,dis,hist
# CATEGORICAL : bar, count, box, swarm, strip, violin
# COMPARISON : joint, pair, cat, matrix, grid

# %%
# -----------------DISTRIBUTIONS/////rugplot------------------------

# %%
plt.figure(figsize=(7,4))
sns.rugplot(data=mpg, x="weight", height=0.5); # height ve alpha 0 ile 1 arasında değer alıyor

# %%
plt.figure(figsize=(7,4))
sns.displot(data=mpg, x="weight");

# %%
plt.figure(figsize=(7,4))
sns.histplot(data=mpg, x="weight");

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", s=200, hue="sex", ax=ax[0])
sns.histplot(data=mpg, x="weight", ax=ax[1])
plt.tight_layout;

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", s=200, hue="sex", ax=ax[0])
sns.displot(data=mpg, x="weight", ax=ax[1])
plt.tight_layout;
# displot hiçbir zaman bir axese girmez

# %%
 plt.figure(figsize=(7,4))
 sns.displot(data=mpg, x="weight", kind="ecdf");

# %%
 plt.figure(figsize=(7,4))
 sns.displot(data=mpg, x="weight", kind="kde");
 # Burada ortaya çıkan alan büyüklüğü 1 e eşittir

# %%
 plt.figure(figsize=(7,4))
 sns.displot(data=mpg, x="weight", kde=True);
 # hist üzerine kde ekliyor

# %%
 plt.figure(figsize=(7,4))
 sns.displot(data=mpg, x="weight", kde=True, aspect=1.5);

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=mpg, x="weight", bins=20);

# %%
fig, ax= plt.subplots(1,2,figsize=(7,4))
sns.histplot(data=mpg, x="weight", ax=ax[0], kde=True)
sns.rugplot(data=mpg, x="weight", ax=ax[1], height=0.5)
plt.tight_layout();

# %%
plt.figure(figsize=(6,4))
sns.set(style="dark")
sns.histplot(data=mpg, x="weight", kde=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.figure(figsize=(7,4))
sns.kdeplot(data=penguins, x="body_mass_g", hue="sex", shade=True);

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(7,4))
sns.kdeplot(data=tips, x="total_bill", y="tip");

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %%
plt.figure(figsize=(7,4))
sns.kdeplot(data=tips, x="total_bill", y="tip", color="red", shade=True);

# %%
fig, ax = plt.subplots(1,2,figsize=(9,4), sharey=True)
sns.scatterplot(data=tips, x="total_bill", y="tip", ax=ax[0])
sns.kdeplot(data=tips, x="total_bill", y="tip", color="red", shade=True, ax=ax[1])
plt.tight_layout();

# %%
plt.figure(figsize=(7,4))
sns.displot(data=penguins, x="body_mass_g", bins=50, rug=True, kde=True);

# %%
# http://seaborn.pydata.org/examples/
# bu siteden örnek kodları ve grafik yapılarını görebilirsin

# %%
plt.figure(figsize=(7,4))
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter");
# yanda hep histplot var içine kind dan yeni grafik çizdirebilirsin
# KIND OLARAK: scatter, kde, hist, hex, reg, resid

# %%
plt.figure(figsize=(7,4))
sns.jointplot(data=tips, x="total_bill", y="tip", kind="kde");
# yanda hep histplot var içine kind dan yeni grafik çizdirebilirsin
# KIND OLARAK: scatter, kde, hist, hex, reg, resid

# %%
plt.figure(figsize=(7,4))
sns.jointplot(data=tips, x="total_bill", y="tip", kind="hist");
# yanda hep histplot var içine kind dan yeni grafik çizdirebilirsin
# KIND OLARAK: scatter, kde, hist, hex, reg, resid

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
plt.figure(figsize=(7,4))
sns.jointplot(data=mpg, x="horsepower", y="acceleration", kind="kde");

# %%
tips[tips.smoker=="No"].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="smoker")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=tips[tips.smoker=="No"], x="total_bill", y="tip")
plt.show()

# %%
plt.figure(figsize=(7,4))
markers={"Male":">", "Female":"<"}
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex", s=150, markers=markers)
plt.show()
# https://matplotlib.org/stable/api/markers_api.html

# %%
# Kernel Density Estimation

# %%
# Plotexpress # Dash # Tableou
