# %%
# ------------02_DVwPYT_BP_02_(Seaborn)-------------
# ---------------Distribution Plots-----------------

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# You will learn, Seaborn plot types under "four main titles" as;
    # Distribution Plots,
        # Histogram
        seaborn.histplot(data=None,x=None, y=None, hue=None, bins='auto', kde=False)
        # Displot
        seaborn.displot(data=None, x=None, y=None, hue=None, rug=False)
        # Kernel Density Estimere (KDE) plot
        seaborn.kdeplot(x=None, y=None, kernel=None, legend=True, hue=None)
    # Categorical Plots,
    # Comparison Plots
    # Matrix Plots.

# There are two types of data in statistics:
    # "numerical"
    # "categorical"
    # numerical: "Age", "weight", "number of something", "shoe size", "total bill"
    # categorical: "Eye color", "gender", "days of the week", "blood type"

# In this lesson, you will learn the following plot types to analyze the numerical data:
    # rugplot, "x ekseninde devamlı bir veri"
    # histogram "x ekseninde belirli aralıklar arasını baz alarak kesintisiz dikey mumlar"
    # KDE "Kernel Density Estimation" plot.
    # "Estimating a Continuous Probability Curve for a finite Data Sample"

# Visualizing "deviation" and "average"
# Out:
#   Input In [3]
#     seaborn.histplot(data=None,x=None, y=None, hue=None, bins='auto', kde=False)
#     ^
# IndentationError: unexpected indent

# %%
df = pd.read_csv("dm_office_sales.csv")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.rugplot(x="salary", data=df)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
sns.rugplot(x="salary", data=df, height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
plt.figure(figsize=(5,4), dpi=100)
sns.rugplot(x="salary", data=df, height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
# do not use distplot DEPRECATED
sns.displot(data=df, x="salary", bins=10)

# %%
sns.displot(data=df, x="salary", bins=100)

# %%
sns.set(style="darkgrid")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="whitegrid")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="white")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="dark")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="ticks")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="darkgrid")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="white")
sns.displot(data=df, x="salary", bins=20)

# %%
sns.set(style="white")
sns.displot(data=df, x="salary", bins=20, color="red")

# %%
sns.set(style="white")
sns.displot(data=df, x="salary", bins=20, color="red", edgecolor="blue")

# %%
sns.set(style="white")
sns.displot(data=df, x="salary", bins=20, color="red", edgecolor="blue", linewidth=4)

# %%
sns.set(style="white")
sns.displot(data=df, x="salary", bins=20, color="red", edgecolor="blue", linewidth=4, ls="--")

# %%
sns.histplot(data=df, x="salary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.displot(data=df, x="salary")

# %%
sns.displot(data=df, x="salary", kde=True)

# %%
sns.displot(data=df, x="salary", kde=True, rug=True)

# %%
sns.kdeplot(data=df, x="salary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
np.random.seed(42)
sample_ages = np.random.randint(0,100,200)

# %%
sample_ages
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample_ages = pd.DataFrame(sample_ages, columns=["age"])

# %%
sns.rugplot(data=sample_ages, x="age" )
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.displot(data=sample_ages, x="age", rug=True, bins=30)

# %%
sns.displot(data=sample_ages, x="age", rug=True, bins=30, kde=True)

# %%
sns.kdeplot(data=sample_ages, x="age")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages, x="age", clip=[0,100])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages, x="age", clip=[0,100], bw_adjust=0.01)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages, x="age", clip=[0,100], bw_adjust=0.1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages, x="age", clip=[0,100], bw_adjust=0.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages, x="age", clip=[0,100], bw_adjust=2)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages, x="age", clip=[0,100], bw_adjust=0.5, shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>
