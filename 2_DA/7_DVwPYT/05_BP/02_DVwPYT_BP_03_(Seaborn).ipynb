# %%
# -----------02_DVwPYT_BP_03_(Seaborn)-------------
# ---------------Categorical Plots-----------------

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# We use the categorical plots when the data set has categories.
# You can see the categories in the pictures above as weather condition
# (drizzle, rain, sun weather, etc) or days of a week (Thur, Fri, Sat, and Sun)

# In this lesson, you will discuss some plots that allow visualizing the categorical data.
# These plots are:
    # barplot,
    seaborn.barplot(x=None, y=None, hue=None, data=None, estimator=function, ci=95)
    # countplot,
    seaborn.countplot(x=None, y=None, hue=None, data=None, orient=None)
    # boxplot,
    seaborn.boxplot(x=None, y=None, hue=None, data=None, orient=None)
    # violinplot,
    seaborn.violinplot(x=None, y=None, hue=None, data=None, palette=None)
    # swarmplot,
    # boxenplot

# Barplot gives also aggragation result about the grouped column value / ci, var, std, max...
# Countplot does not give these info
# Out:
#   Input In [103]
#     seaborn.barplot(x=None, y=None, hue=None, data=None, estimator=function, ci=95)
#     ^
# IndentationError: unexpected indent

# %%
df = pd.read_csv("dm_office_sales.csv")

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df["division"].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %% [markdown]
# ### COUNTPLOT

# %%
sns.countplot(data=df, x="division")
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df, x="division")
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df, x="division")
plt.ylim(90,260)
# Out:
# (90.0, 260.0)

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df, x="division")
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df, x="level of education")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
df["level of education"].value_counts()
# Out:
# associate's degree    412
# some college          392
# high school           108
# bachelor's degree      85
# master's degree         3
# Name: level of education, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df, x="level of education", hue="division")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.countplot(data=df, x="level of education", hue="division", palette="Set2")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %% [markdown]
# ### BARPLOT

# %%
# eğitim seviyelerine göre maaşların ortalamasını ve bundaki sd yi gösteren bar tip grafik
plt.figure(figsize=(10,4), dpi=100)
sns.barplot(data=df, x="level of education", y="salary", estimator=np.mean, ci="sd")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(10,4), dpi=100)
sns.barplot(data=df, x="level of education", y="salary", estimator=np.mean, ci="sd", hue="division")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(10,4), dpi=100)
sns.barplot(data=df, x="level of education", y="salary", estimator=np.mean, ci="sd", hue="division")
plt.legend(bbox_to_anchor=(1.05,1))

# %%
# DISTRUBITIONS WITHIN CATEGORIES
    # BOXPLOT (IQR)
    # VIOLINPLOT (Mirror)
    # SWARMPLOT (Sürü)
    # BOXENPLOT

# %% [markdown]
# ### BOXPLOT

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.boxplot(data=df, y="math score")
# Out:
# <AxesSubplot:ylabel='math score'>

# %%
sns.boxplot(data=df, x="math score")
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
plt.figure(figsize=(10,4), dpi=100)
sns.boxplot(data=df, x="test preparation course", y="math score")
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='math score'>

# %%
plt.figure(figsize=(10,4), dpi=100)
sns.boxplot(data=df, x="test preparation course", y="reading score")
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='reading score'>

# %%
plt.figure(figsize=(10,4), dpi=100)
sns.boxplot(data=df, x="parental level of education", y="reading score", hue="test preparation course")
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='reading score'>

# %%
plt.figure(figsize=(10,4), dpi=100)
sns.boxplot(data=df, x="parental level of education", y="reading score", hue="test preparation course")
plt.legend(bbox_to_anchor=(1.04,1))

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.boxplot(data=df, x="reading score", y="parental level of education", hue="test preparation course")
plt.legend(bbox_to_anchor=(1.04,0.5))

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.boxplot(data=df, x="reading score", y="parental level of education", hue="test preparation course", palette="Set2")
plt.legend(bbox_to_anchor=(1.04,0.5))

# %% [markdown]
# ### VIOLINPLOT

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", hue="test preparation course", palette="Set2")
plt.legend(bbox_to_anchor=(1.2,0.5))

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", hue="test preparation course", palette="Set2", split=True)
plt.legend(bbox_to_anchor=(1.2,0.5))

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", hue="test preparation course", palette="Set2", split=True, inner=None)
plt.legend(bbox_to_anchor=(1.2,0.5))

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", hue="test preparation course", palette="Set2", split=True, inner="quartile")
plt.legend(bbox_to_anchor=(1.2,0.5))

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", split=True, inner="quartile")
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", split=True, inner="stick")
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", bw=0.1)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", bw=0.5)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.violinplot(data=df, x="reading score", y="parental level of education", bw=0.01)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %% [markdown]
# ### SWARMPLOT

# %%
sns.swarmplot(data=df, x="math score")
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
sns.swarmplot(data=df, x="math score", size=2)
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
plt.figure(figsize=(8,4), dpi=100)
sns.swarmplot(data=df, x="math score", size=2)
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
plt.figure(figsize=(8,4), dpi=100)
sns.swarmplot(data=df, x="math score", y= "gender", size=2)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='gender'>

# %%
plt.figure(figsize=(8,4), dpi=100)
sns.swarmplot(data=df, x="math score", y= "gender", size=2, hue="test preparation course")
plt.legend(bbox_to_anchor=(1.25, 0.6))

# %%
plt.figure(figsize=(8,4), dpi=100)
sns.swarmplot(data=df, x="math score", y= "gender", size=2, hue="test preparation course", dodge=True)
plt.legend(bbox_to_anchor=(1.25, 0.6))

# %% [markdown]
# ### BOXENPLOT

# %%
sns.boxenplot(data=df, x="math score", y="test preparation course")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='test preparation course'>

# %%
sns.boxenplot(data=df, x="math score", y="test preparation course", hue="gender")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='test preparation course'>

# %%
sns.boxplot(data=df, x="math score", y="test preparation course", hue="gender")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='test preparation course'>
